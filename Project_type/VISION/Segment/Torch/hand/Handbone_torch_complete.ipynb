# %% [markdown]
# <a href="https://colab.research.google.com/github/kikiru328/Study_Notebook/blob/main/Torch_b11one_Unet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### MODULE IMPORT

# %%
import os

import numpy as np
import cv2
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras import backend as keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

from glob import glob
from tqdm import tqdm

from PIL import Image

# %% [markdown]
# ### Data copy

# %%
import os
import shutil
shutil.copytree('/content/drive/MyDrive/unetimgs','/content/bone')
# Out:
# '/content/bone'

# %%
pwd
# Out:
# '/content'

# %%
# !git clone https://github.com/hanyoseob/youtube-cnn-002-pytorch-unet.git
# Out:
# Cloning into 'youtube-cnn-002-pytorch-unet'...
# remote: Enumerating objects: 65, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 65 (delta 29), reused 52 (delta 16), pack-reused 0
# Unpacking objects: 100% (65/65), done.

# %%
# %cd /content/youtube-cnn-002-pytorch-unet
# Out:
# /content/youtube-cnn-002-pytorch-unet

# %%
! rm -rf '/content/youtube-cnn-002-pytorch-unet/datasets/train'

# %%
TRAIN_PATH = '/content/youtube-cnn-002-pytorch-unet/datasets/train'
Val_PATH = '/content/youtube-cnn-002-pytorch-unet/datasets/val'
TEST_PATH = '/content/youtube-cnn-002-pytorch-unet/datasets/test'
SAVE_PATH = '/content/youtube-cnn-002-pytorch-unet/datasets/save'

Mask_path = '/content/bone/datasets/masks/train'

# print(TRAIN_PATH)
masks = glob('/content/bone/datasets/masks/train/*.png')
masks = sorted(masks)


WIDTH = 800
HEIGHT = 800

rows = 4
cols = 4

for num, mask in enumerate(masks):
    # print(mask)
    image = cv2.imread(mask, cv2.IMREAD_GRAYSCALE)
    # print(image)
    im_np = np.asarray(image)
    # print(im_np.shape)
    grey_image = cv2.resize(im_np,(WIDTH,HEIGHT)).astype('float64')
    print(grey_image.shape)
    grey_image = grey_image.reshape(WIDTH,HEIGHT)
    # print(grey_image.shape)
    im = Image.fromarray(grey_image)

    if not os.path.exists(SAVE_PATH):
        os.makedirs(SAVE_PATH)
    if not os.path.exists(Val_PATH):
        os.makedirs(Val_PATH)
    if not os.path.exists(TEST_PATH):
        os.makedirs(TEST_PATH)
    if not os.path.exists(TRAIN_PATH):
        os.makedirs(TRAIN_PATH)
        
    np.save(TRAIN_PATH+'/'+'label_%03d.npy' % num, im)
# Out:
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)

# %%
label1 = np.load('/content/youtube-cnn-002-pytorch-unet/datasets/train/label_001.npy')
label1.shape
# Out:
# (800, 800)

# %%
img_path = '/content/bone/datasets/imgs/train'

bones = glob(img_path + '/*.jpg')
bones = sorted(bones)

WIDTH = 800
HEIGHT = 800

rows = 4
cols = 4

bones_box = np.zeros((len(bones),WIDTH,HEIGHT))
# print(bones_box)
for num, bone in enumerate(bones):

    image_pil = cv2.imread(bone, cv2.IMREAD_GRAYSCALE)
    # print(image_pil)
    image = np.array(image_pil)
    # print(image.shape)
    grey_image = cv2.resize(image,(WIDTH,HEIGHT)).astype('float64')
    # print(grey_image.shape)
    grey_image = grey_image.reshape(WIDTH,HEIGHT)
    print(grey_image.shape)
    bones_box[num] = grey_image
    # print(bones_box)
    im = Image.fromarray(grey_image)
    # print(im)
    # np.save(TRAIN_PATH+'/'+'input_%03d.npy' % num, im)
# Out:
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)
# (800, 800)

# %%
input1 = np.load('/content/youtube-cnn-002-pytorch-unet/datasets/train/input_001.npy')
input1.shape
# Out:
# (800, 800)

# %%
plt.figure(figsize=(30,30))

plt.subplot(121)
plt.imshow(label1, cmap='gray')
plt.title('label')

plt.subplot(122)
plt.imshow(input1, cmap='gray')
plt.title('input')

plt.show()

# %%
plt.imshow(input1)
input1.shape
# Out:
# (800, 800)

# %%
pwd
# Out:
# '/content/youtube-cnn-002-pytorch-unet'

# %%
# %cd '/content/youtube-cnn-002-pytorch-unet'
# Out:
# /content/youtube-cnn-002-pytorch-unet

# %%
# !python train.py
# Out:
# learning rate: 1.0000e-03
# batch size: 2
# number of epoch: 100
# data dir: ./datasets
# ckpt dir: ./checkpoint
# log dir: ./log
# result dir: ./result
# mode: train
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# TRAIN: EPOCH 0001 / 0100 | BATCH 0001 / 0011 | LOSS 0.6695
# TRAIN: EPOCH 0001 / 0100 | BATCH 0002 / 0011 | LOSS 0.6035
# TRAIN: EPOCH 0001 / 0100 | BATCH 0003 / 0011 | LOSS 0.5711
# TRAIN: EPOCH 0001 / 0100 | BATCH 0004 / 0011 | LOSS 0.5515
# TRAIN: EPOCH 0001 / 0100 | BATCH 0005 / 0011 | LOSS 0.5278
# TRAIN: EPOCH 0001 / 0100 | BATCH 0006 / 0011 | LOSS 0.5097
# TRAIN: EPOCH 0001 / 0100 | BATCH 0007 / 0011 | LOSS 0.4927
# TRAIN: EPOCH 0001 / 0100 | BATCH 0008 / 0011 | LOSS 0.4763
# TRAIN: EPOCH 0001 / 0100 | BATCH 0009 / 0011 | LOSS 0.4638
# TRAIN: EPOCH 0001 / 0100 | BATCH 0010 / 0011 | LOSS 0.4553
# TRAIN: EPOCH 0001 / 0100 | BATCH 0011 / 0011 | LOSS 0.4480
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# TRAIN: EPOCH 0002 / 0100 | BATCH 0001 / 0011 | LOSS 0.3601
# TRAIN: EPOCH 0002 / 0100 | BATCH 0002 / 0011 | LOSS 0.3393
# TRAIN: EPOCH 0002 / 0100 | BATCH 0003 / 0011 | LOSS 0.3334
# TRAIN: EPOCH 0002 / 0100 | BATCH 0004 / 0011 | LOSS 0.3290
# TRAIN: EPOCH 0002 / 0100 | BATCH 0005 / 0011 | LOSS 0.3227
# TRAIN: EPOCH 0002 / 0100 | BATCH 0006 / 0011 | LOSS 0.3202
# TRAIN: EPOCH 0002 / 0100 | BATCH 0007 / 0011 | LOSS 0.3178
# TRAIN: EPOCH 0002 / 0100 | BATCH 0008 / 0011 | LOSS 0.3144
# TRAIN: EPOCH 0002 / 0100 | BATCH 0009 / 0011 | LOSS 0.3113
# TRAIN: EPOCH 0002 / 0100 | BATCH 0010 / 0011 | LOSS 0.3073
# TRAIN: EPOCH 0002 / 0100 | BATCH 0011 / 0011 | LOSS 0.3036
# TRAIN: EPOCH 0003 / 0100 | BATCH 0001 / 0011 | LOSS 0.2731
# TRAIN: EPOCH 0003 / 0100 | BATCH 0002 / 0011 | LOSS 0.2620
# TRAIN: EPOCH 0003 / 0100 | BATCH 0003 / 0011 | LOSS 0.2554
# TRAIN: EPOCH 0003 / 0100 | BATCH 0004 / 0011 | LOSS 0.2604
# TRAIN: EPOCH 0003 / 0100 | BATCH 0005 / 0011 | LOSS 0.2536
# TRAIN: EPOCH 0003 / 0100 | BATCH 0006 / 0011 | LOSS 0.2528
# TRAIN: EPOCH 0003 / 0100 | BATCH 0007 / 0011 | LOSS 0.2570
# TRAIN: EPOCH 0003 / 0100 | BATCH 0008 / 0011 | LOSS 0.2520
# TRAIN: EPOCH 0003 / 0100 | BATCH 0009 / 0011 | LOSS 0.2507
# TRAIN: EPOCH 0003 / 0100 | BATCH 0010 / 0011 | LOSS 0.2478
# TRAIN: EPOCH 0003 / 0100 | BATCH 0011 / 0011 | LOSS 0.2436
# TRAIN: EPOCH 0004 / 0100 | BATCH 0001 / 0011 | LOSS 0.2118
# TRAIN: EPOCH 0004 / 0100 | BATCH 0002 / 0011 | LOSS 0.2076
# TRAIN: EPOCH 0004 / 0100 | BATCH 0003 / 0011 | LOSS 0.2035
# TRAIN: EPOCH 0004 / 0100 | BATCH 0004 / 0011 | LOSS 0.2050
# TRAIN: EPOCH 0004 / 0100 | BATCH 0005 / 0011 | LOSS 0.2051
# TRAIN: EPOCH 0004 / 0100 | BATCH 0006 / 0011 | LOSS 0.2017
# TRAIN: EPOCH 0004 / 0100 | BATCH 0007 / 0011 | LOSS 0.2008
# TRAIN: EPOCH 0004 / 0100 | BATCH 0008 / 0011 | LOSS 0.1993
# TRAIN: EPOCH 0004 / 0100 | BATCH 0009 / 0011 | LOSS 0.1977
# TRAIN: EPOCH 0004 / 0100 | BATCH 0010 / 0011 | LOSS 0.1958
# TRAIN: EPOCH 0004 / 0100 | BATCH 0011 / 0011 | LOSS 0.1954
# TRAIN: EPOCH 0005 / 0100 | BATCH 0001 / 0011 | LOSS 0.1702
# TRAIN: EPOCH 0005 / 0100 | BATCH 0002 / 0011 | LOSS 0.1850
# TRAIN: EPOCH 0005 / 0100 | BATCH 0003 / 0011 | LOSS 0.1813
# TRAIN: EPOCH 0005 / 0100 | BATCH 0004 / 0011 | LOSS 0.1728
# TRAIN: EPOCH 0005 / 0100 | BATCH 0005 / 0011 | LOSS 0.1744
# TRAIN: EPOCH 0005 / 0100 | BATCH 0006 / 0011 | LOSS 0.1778
# TRAIN: EPOCH 0005 / 0100 | BATCH 0007 / 0011 | LOSS 0.1800
# TRAIN: EPOCH 0005 / 0100 | BATCH 0008 / 0011 | LOSS 0.1761
# TRAIN: EPOCH 0005 / 0100 | BATCH 0009 / 0011 | LOSS 0.1726
# TRAIN: EPOCH 0005 / 0100 | BATCH 0010 / 0011 | LOSS 0.1706
# TRAIN: EPOCH 0005 / 0100 | BATCH 0011 / 0011 | LOSS 0.1783
# TRAIN: EPOCH 0006 / 0100 | BATCH 0001 / 0011 | LOSS 0.1669
# TRAIN: EPOCH 0006 / 0100 | BATCH 0002 / 0011 | LOSS 0.1778
# TRAIN: EPOCH 0006 / 0100 | BATCH 0003 / 0011 | LOSS 0.1689
# TRAIN: EPOCH 0006 / 0100 | BATCH 0004 / 0011 | LOSS 0.1707
# TRAIN: EPOCH 0006 / 0100 | BATCH 0005 / 0011 | LOSS 0.1666
# TRAIN: EPOCH 0006 / 0100 | BATCH 0006 / 0011 | LOSS 0.1642
# TRAIN: EPOCH 0006 / 0100 | BATCH 0007 / 0011 | LOSS 0.1628
# TRAIN: EPOCH 0006 / 0100 | BATCH 0008 / 0011 | LOSS 0.1628
# TRAIN: EPOCH 0006 / 0100 | BATCH 0009 / 0011 | LOSS 0.1590
# TRAIN: EPOCH 0006 / 0100 | BATCH 0010 / 0011 | LOSS 0.1593
# TRAIN: EPOCH 0006 / 0100 | BATCH 0011 / 0011 | LOSS 0.1639
# TRAIN: EPOCH 0007 / 0100 | BATCH 0001 / 0011 | LOSS 0.1494
# TRAIN: EPOCH 0007 / 0100 | BATCH 0002 / 0011 | LOSS 0.1496
# TRAIN: EPOCH 0007 / 0100 | BATCH 0003 / 0011 | LOSS 0.1536
# TRAIN: EPOCH 0007 / 0100 | BATCH 0004 / 0011 | LOSS 0.1462
# TRAIN: EPOCH 0007 / 0100 | BATCH 0005 / 0011 | LOSS 0.1414
# TRAIN: EPOCH 0007 / 0100 | BATCH 0006 / 0011 | LOSS 0.1449
# TRAIN: EPOCH 0007 / 0100 | BATCH 0007 / 0011 | LOSS 0.1436
# TRAIN: EPOCH 0007 / 0100 | BATCH 0008 / 0011 | LOSS 0.1440
# TRAIN: EPOCH 0007 / 0100 | BATCH 0009 / 0011 | LOSS 0.1468
# TRAIN: EPOCH 0007 / 0100 | BATCH 0010 / 0011 | LOSS 0.1440
# TRAIN: EPOCH 0007 / 0100 | BATCH 0011 / 0011 | LOSS 0.1442
# TRAIN: EPOCH 0008 / 0100 | BATCH 0001 / 0011 | LOSS 0.1197
# TRAIN: EPOCH 0008 / 0100 | BATCH 0002 / 0011 | LOSS 0.1159
# TRAIN: EPOCH 0008 / 0100 | BATCH 0003 / 0011 | LOSS 0.1138
# TRAIN: EPOCH 0008 / 0100 | BATCH 0004 / 0011 | LOSS 0.1275
# TRAIN: EPOCH 0008 / 0100 | BATCH 0005 / 0011 | LOSS 0.1228
# TRAIN: EPOCH 0008 / 0100 | BATCH 0006 / 0011 | LOSS 0.1192
# TRAIN: EPOCH 0008 / 0100 | BATCH 0007 / 0011 | LOSS 0.1231
# TRAIN: EPOCH 0008 / 0100 | BATCH 0008 / 0011 | LOSS 0.1194
# TRAIN: EPOCH 0008 / 0100 | BATCH 0009 / 0011 | LOSS 0.1242
# TRAIN: EPOCH 0008 / 0100 | BATCH 0010 / 0011 | LOSS 0.1228
# TRAIN: EPOCH 0008 / 0100 | BATCH 0011 / 0011 | LOSS 0.1286
# TRAIN: EPOCH 0009 / 0100 | BATCH 0001 / 0011 | LOSS 0.1151
# TRAIN: EPOCH 0009 / 0100 | BATCH 0002 / 0011 | LOSS 0.1197
# TRAIN: EPOCH 0009 / 0100 | BATCH 0003 / 0011 | LOSS 0.1272
# TRAIN: EPOCH 0009 / 0100 | BATCH 0004 / 0011 | LOSS 0.1244
# TRAIN: EPOCH 0009 / 0100 | BATCH 0005 / 0011 | LOSS 0.1210
# TRAIN: EPOCH 0009 / 0100 | BATCH 0006 / 0011 | LOSS 0.1212
# TRAIN: EPOCH 0009 / 0100 | BATCH 0007 / 0011 | LOSS 0.1228
# TRAIN: EPOCH 0009 / 0100 | BATCH 0008 / 0011 | LOSS 0.1238
# TRAIN: EPOCH 0009 / 0100 | BATCH 0009 / 0011 | LOSS 0.1212
# TRAIN: EPOCH 0009 / 0100 | BATCH 0010 / 0011 | LOSS 0.1177
# TRAIN: EPOCH 0009 / 0100 | BATCH 0011 / 0011 | LOSS 0.1155
# TRAIN: EPOCH 0010 / 0100 | BATCH 0001 / 0011 | LOSS 0.0937
# TRAIN: EPOCH 0010 / 0100 | BATCH 0002 / 0011 | LOSS 0.1000
# TRAIN: EPOCH 0010 / 0100 | BATCH 0003 / 0011 | LOSS 0.0962
# TRAIN: EPOCH 0010 / 0100 | BATCH 0004 / 0011 | LOSS 0.1005
# TRAIN: EPOCH 0010 / 0100 | BATCH 0005 / 0011 | LOSS 0.1086
# TRAIN: EPOCH 0010 / 0100 | BATCH 0006 / 0011 | LOSS 0.1109
# TRAIN: EPOCH 0010 / 0100 | BATCH 0007 / 0011 | LOSS 0.1145
# TRAIN: EPOCH 0010 / 0100 | BATCH 0008 / 0011 | LOSS 0.1101
# TRAIN: EPOCH 0010 / 0100 | BATCH 0009 / 0011 | LOSS 0.1093
# TRAIN: EPOCH 0010 / 0100 | BATCH 0010 / 0011 | LOSS 0.1100
# TRAIN: EPOCH 0010 / 0100 | BATCH 0011 / 0011 | LOSS 0.1081
# TRAIN: EPOCH 0011 / 0100 | BATCH 0001 / 0011 | LOSS 0.1125
# TRAIN: EPOCH 0011 / 0100 | BATCH 0002 / 0011 | LOSS 0.1100
# TRAIN: EPOCH 0011 / 0100 | BATCH 0003 / 0011 | LOSS 0.1142
# TRAIN: EPOCH 0011 / 0100 | BATCH 0004 / 0011 | LOSS 0.1043
# TRAIN: EPOCH 0011 / 0100 | BATCH 0005 / 0011 | LOSS 0.1095
# TRAIN: EPOCH 0011 / 0100 | BATCH 0006 / 0011 | LOSS 0.1046
# TRAIN: EPOCH 0011 / 0100 | BATCH 0007 / 0011 | LOSS 0.1029
# TRAIN: EPOCH 0011 / 0100 | BATCH 0008 / 0011 | LOSS 0.1061
# TRAIN: EPOCH 0011 / 0100 | BATCH 0009 / 0011 | LOSS 0.1067
# TRAIN: EPOCH 0011 / 0100 | BATCH 0010 / 0011 | LOSS 0.1080
# TRAIN: EPOCH 0011 / 0100 | BATCH 0011 / 0011 | LOSS 0.1099
# TRAIN: EPOCH 0012 / 0100 | BATCH 0001 / 0011 | LOSS 0.0742
# TRAIN: EPOCH 0012 / 0100 | BATCH 0002 / 0011 | LOSS 0.0798
# TRAIN: EPOCH 0012 / 0100 | BATCH 0003 / 0011 | LOSS 0.0821
# TRAIN: EPOCH 0012 / 0100 | BATCH 0004 / 0011 | LOSS 0.0853
# TRAIN: EPOCH 0012 / 0100 | BATCH 0005 / 0011 | LOSS 0.0945
# TRAIN: EPOCH 0012 / 0100 | BATCH 0006 / 0011 | LOSS 0.0919
# TRAIN: EPOCH 0012 / 0100 | BATCH 0007 / 0011 | LOSS 0.0949
# TRAIN: EPOCH 0012 / 0100 | BATCH 0008 / 0011 | LOSS 0.0917
# TRAIN: EPOCH 0012 / 0100 | BATCH 0009 / 0011 | LOSS 0.0928
# TRAIN: EPOCH 0012 / 0100 | BATCH 0010 / 0011 | LOSS 0.0928
# TRAIN: EPOCH 0012 / 0100 | BATCH 0011 / 0011 | LOSS 0.1024
# TRAIN: EPOCH 0013 / 0100 | BATCH 0001 / 0011 | LOSS 0.1072
# TRAIN: EPOCH 0013 / 0100 | BATCH 0002 / 0011 | LOSS 0.1082
# TRAIN: EPOCH 0013 / 0100 | BATCH 0003 / 0011 | LOSS 0.1085
# TRAIN: EPOCH 0013 / 0100 | BATCH 0004 / 0011 | LOSS 0.1096
# TRAIN: EPOCH 0013 / 0100 | BATCH 0005 / 0011 | LOSS 0.1087
# TRAIN: EPOCH 0013 / 0100 | BATCH 0006 / 0011 | LOSS 0.1116
# TRAIN: EPOCH 0013 / 0100 | BATCH 0007 / 0011 | LOSS 0.1067
# TRAIN: EPOCH 0013 / 0100 | BATCH 0008 / 0011 | LOSS 0.1066
# TRAIN: EPOCH 0013 / 0100 | BATCH 0009 / 0011 | LOSS 0.1028
# TRAIN: EPOCH 0013 / 0100 | BATCH 0010 / 0011 | LOSS 0.1010
# TRAIN: EPOCH 0013 / 0100 | BATCH 0011 / 0011 | LOSS 0.0996
# TRAIN: EPOCH 0014 / 0100 | BATCH 0001 / 0011 | LOSS 0.0839
# TRAIN: EPOCH 0014 / 0100 | BATCH 0002 / 0011 | LOSS 0.0937
# TRAIN: EPOCH 0014 / 0100 | BATCH 0003 / 0011 | LOSS 0.0905
# TRAIN: EPOCH 0014 / 0100 | BATCH 0004 / 0011 | LOSS 0.0910
# TRAIN: EPOCH 0014 / 0100 | BATCH 0005 / 0011 | LOSS 0.0866
# TRAIN: EPOCH 0014 / 0100 | BATCH 0006 / 0011 | LOSS 0.0976
# TRAIN: EPOCH 0014 / 0100 | BATCH 0007 / 0011 | LOSS 0.0943
# TRAIN: EPOCH 0014 / 0100 | BATCH 0008 / 0011 | LOSS 0.0912
# TRAIN: EPOCH 0014 / 0100 | BATCH 0009 / 0011 | LOSS 0.0887
# TRAIN: EPOCH 0014 / 0100 | BATCH 0010 / 0011 | LOSS 0.0902
# TRAIN: EPOCH 0014 / 0100 | BATCH 0011 / 0011 | LOSS 0.0879
# TRAIN: EPOCH 0015 / 0100 | BATCH 0001 / 0011 | LOSS 0.0682
# TRAIN: EPOCH 0015 / 0100 | BATCH 0002 / 0011 | LOSS 0.0777
# TRAIN: EPOCH 0015 / 0100 | BATCH 0003 / 0011 | LOSS 0.0796
# TRAIN: EPOCH 0015 / 0100 | BATCH 0004 / 0011 | LOSS 0.1042
# TRAIN: EPOCH 0015 / 0100 | BATCH 0005 / 0011 | LOSS 0.1089
# TRAIN: EPOCH 0015 / 0100 | BATCH 0006 / 0011 | LOSS 0.1035
# TRAIN: EPOCH 0015 / 0100 | BATCH 0007 / 0011 | LOSS 0.0970
# TRAIN: EPOCH 0015 / 0100 | BATCH 0008 / 0011 | LOSS 0.0951
# TRAIN: EPOCH 0015 / 0100 | BATCH 0009 / 0011 | LOSS 0.0923
# TRAIN: EPOCH 0015 / 0100 | BATCH 0010 / 0011 | LOSS 0.0904
# TRAIN: EPOCH 0015 / 0100 | BATCH 0011 / 0011 | LOSS 0.0895
# TRAIN: EPOCH 0016 / 0100 | BATCH 0001 / 0011 | LOSS 0.0864
# TRAIN: EPOCH 0016 / 0100 | BATCH 0002 / 0011 | LOSS 0.0745
# TRAIN: EPOCH 0016 / 0100 | BATCH 0003 / 0011 | LOSS 0.0703
# TRAIN: EPOCH 0016 / 0100 | BATCH 0004 / 0011 | LOSS 0.0796
# TRAIN: EPOCH 0016 / 0100 | BATCH 0005 / 0011 | LOSS 0.0895
# TRAIN: EPOCH 0016 / 0100 | BATCH 0006 / 0011 | LOSS 0.0838
# TRAIN: EPOCH 0016 / 0100 | BATCH 0007 / 0011 | LOSS 0.0861
# TRAIN: EPOCH 0016 / 0100 | BATCH 0008 / 0011 | LOSS 0.0826
# TRAIN: EPOCH 0016 / 0100 | BATCH 0009 / 0011 | LOSS 0.0807
# TRAIN: EPOCH 0016 / 0100 | BATCH 0010 / 0011 | LOSS 0.0850
# TRAIN: EPOCH 0016 / 0100 | BATCH 0011 / 0011 | LOSS 0.0931
# TRAIN: EPOCH 0017 / 0100 | BATCH 0001 / 0011 | LOSS 0.1123
# TRAIN: EPOCH 0017 / 0100 | BATCH 0002 / 0011 | LOSS 0.1001
# TRAIN: EPOCH 0017 / 0100 | BATCH 0003 / 0011 | LOSS 0.0894
# TRAIN: EPOCH 0017 / 0100 | BATCH 0004 / 0011 | LOSS 0.0927
# TRAIN: EPOCH 0017 / 0100 | BATCH 0005 / 0011 | LOSS 0.0884
# TRAIN: EPOCH 0017 / 0100 | BATCH 0006 / 0011 | LOSS 0.0918
# TRAIN: EPOCH 0017 / 0100 | BATCH 0007 / 0011 | LOSS 0.0881
# TRAIN: EPOCH 0017 / 0100 | BATCH 0008 / 0011 | LOSS 0.0864
# TRAIN: EPOCH 0017 / 0100 | BATCH 0009 / 0011 | LOSS 0.0843
# TRAIN: EPOCH 0017 / 0100 | BATCH 0010 / 0011 | LOSS 0.0890
# TRAIN: EPOCH 0017 / 0100 | BATCH 0011 / 0011 | LOSS 0.0864
# TRAIN: EPOCH 0018 / 0100 | BATCH 0001 / 0011 | LOSS 0.1476
# TRAIN: EPOCH 0018 / 0100 | BATCH 0002 / 0011 | LOSS 0.1139
# TRAIN: EPOCH 0018 / 0100 | BATCH 0003 / 0011 | LOSS 0.1024
# TRAIN: EPOCH 0018 / 0100 | BATCH 0004 / 0011 | LOSS 0.1008
# TRAIN: EPOCH 0018 / 0100 | BATCH 0005 / 0011 | LOSS 0.1051
# TRAIN: EPOCH 0018 / 0100 | BATCH 0006 / 0011 | LOSS 0.0985
# TRAIN: EPOCH 0018 / 0100 | BATCH 0007 / 0011 | LOSS 0.0926
# TRAIN: EPOCH 0018 / 0100 | BATCH 0008 / 0011 | LOSS 0.0903
# TRAIN: EPOCH 0018 / 0100 | BATCH 0009 / 0011 | LOSS 0.0871
# TRAIN: EPOCH 0018 / 0100 | BATCH 0010 / 0011 | LOSS 0.0849
# TRAIN: EPOCH 0018 / 0100 | BATCH 0011 / 0011 | LOSS 0.0845
# TRAIN: EPOCH 0019 / 0100 | BATCH 0001 / 0011 | LOSS 0.0696
# TRAIN: EPOCH 0019 / 0100 | BATCH 0002 / 0011 | LOSS 0.0616
# TRAIN: EPOCH 0019 / 0100 | BATCH 0003 / 0011 | LOSS 0.0582
# TRAIN: EPOCH 0019 / 0100 | BATCH 0004 / 0011 | LOSS 0.0564
# TRAIN: EPOCH 0019 / 0100 | BATCH 0005 / 0011 | LOSS 0.0669
# TRAIN: EPOCH 0019 / 0100 | BATCH 0006 / 0011 | LOSS 0.0718
# TRAIN: EPOCH 0019 / 0100 | BATCH 0007 / 0011 | LOSS 0.0720
# TRAIN: EPOCH 0019 / 0100 | BATCH 0008 / 0011 | LOSS 0.0702
# TRAIN: EPOCH 0019 / 0100 | BATCH 0009 / 0011 | LOSS 0.0698
# TRAIN: EPOCH 0019 / 0100 | BATCH 0010 / 0011 | LOSS 0.0762
# TRAIN: EPOCH 0019 / 0100 | BATCH 0011 / 0011 | LOSS 0.0852
# TRAIN: EPOCH 0020 / 0100 | BATCH 0001 / 0011 | LOSS 0.1274
# TRAIN: EPOCH 0020 / 0100 | BATCH 0002 / 0011 | LOSS 0.0889
# TRAIN: EPOCH 0020 / 0100 | BATCH 0003 / 0011 | LOSS 0.0787
# TRAIN: EPOCH 0020 / 0100 | BATCH 0004 / 0011 | LOSS 0.0723
# TRAIN: EPOCH 0020 / 0100 | BATCH 0005 / 0011 | LOSS 0.0799
# TRAIN: EPOCH 0020 / 0100 | BATCH 0006 / 0011 | LOSS 0.0779
# TRAIN: EPOCH 0020 / 0100 | BATCH 0007 / 0011 | LOSS 0.0760
# TRAIN: EPOCH 0020 / 0100 | BATCH 0008 / 0011 | LOSS 0.0738
# TRAIN: EPOCH 0020 / 0100 | BATCH 0009 / 0011 | LOSS 0.0758
# TRAIN: EPOCH 0020 / 0100 | BATCH 0010 / 0011 | LOSS 0.0771
# TRAIN: EPOCH 0020 / 0100 | BATCH 0011 / 0011 | LOSS 0.0746
# TRAIN: EPOCH 0021 / 0100 | BATCH 0001 / 0011 | LOSS 0.1179
# TRAIN: EPOCH 0021 / 0100 | BATCH 0002 / 0011 | LOSS 0.1030
# TRAIN: EPOCH 0021 / 0100 | BATCH 0003 / 0011 | LOSS 0.0869
# TRAIN: EPOCH 0021 / 0100 | BATCH 0004 / 0011 | LOSS 0.0778
# TRAIN: EPOCH 0021 / 0100 | BATCH 0005 / 0011 | LOSS 0.0799
# TRAIN: EPOCH 0021 / 0100 | BATCH 0006 / 0011 | LOSS 0.0750
# TRAIN: EPOCH 0021 / 0100 | BATCH 0007 / 0011 | LOSS 0.0765
# TRAIN: EPOCH 0021 / 0100 | BATCH 0008 / 0011 | LOSS 0.0738
# TRAIN: EPOCH 0021 / 0100 | BATCH 0009 / 0011 | LOSS 0.0760
# TRAIN: EPOCH 0021 / 0100 | BATCH 0010 / 0011 | LOSS 0.0747
# TRAIN: EPOCH 0021 / 0100 | BATCH 0011 / 0011 | LOSS 0.0737
# TRAIN: EPOCH 0022 / 0100 | BATCH 0001 / 0011 | LOSS 0.0497
# TRAIN: EPOCH 0022 / 0100 | BATCH 0002 / 0011 | LOSS 0.0594
# TRAIN: EPOCH 0022 / 0100 | BATCH 0003 / 0011 | LOSS 0.0550
# TRAIN: EPOCH 0022 / 0100 | BATCH 0004 / 0011 | LOSS 0.0535
# TRAIN: EPOCH 0022 / 0100 | BATCH 0005 / 0011 | LOSS 0.0646
# TRAIN: EPOCH 0022 / 0100 | BATCH 0006 / 0011 | LOSS 0.0696
# TRAIN: EPOCH 0022 / 0100 | BATCH 0007 / 0011 | LOSS 0.0744
# TRAIN: EPOCH 0022 / 0100 | BATCH 0008 / 0011 | LOSS 0.0723
# TRAIN: EPOCH 0022 / 0100 | BATCH 0009 / 0011 | LOSS 0.0763
# TRAIN: EPOCH 0022 / 0100 | BATCH 0010 / 0011 | LOSS 0.0753
# TRAIN: EPOCH 0022 / 0100 | BATCH 0011 / 0011 | LOSS 0.0730
# TRAIN: EPOCH 0023 / 0100 | BATCH 0001 / 0011 | LOSS 0.0806
# TRAIN: EPOCH 0023 / 0100 | BATCH 0002 / 0011 | LOSS 0.0635
# TRAIN: EPOCH 0023 / 0100 | BATCH 0003 / 0011 | LOSS 0.0623
# TRAIN: EPOCH 0023 / 0100 | BATCH 0004 / 0011 | LOSS 0.0609
# TRAIN: EPOCH 0023 / 0100 | BATCH 0005 / 0011 | LOSS 0.0587
# TRAIN: EPOCH 0023 / 0100 | BATCH 0006 / 0011 | LOSS 0.0609
# TRAIN: EPOCH 0023 / 0100 | BATCH 0007 / 0011 | LOSS 0.0672
# TRAIN: EPOCH 0023 / 0100 | BATCH 0008 / 0011 | LOSS 0.0643
# TRAIN: EPOCH 0023 / 0100 | BATCH 0009 / 0011 | LOSS 0.0626
# TRAIN: EPOCH 0023 / 0100 | BATCH 0010 / 0011 | LOSS 0.0662
# TRAIN: EPOCH 0023 / 0100 | BATCH 0011 / 0011 | LOSS 0.0788
# TRAIN: EPOCH 0024 / 0100 | BATCH 0001 / 0011 | LOSS 0.1010
# TRAIN: EPOCH 0024 / 0100 | BATCH 0002 / 0011 | LOSS 0.0917
# TRAIN: EPOCH 0024 / 0100 | BATCH 0003 / 0011 | LOSS 0.0824
# TRAIN: EPOCH 0024 / 0100 | BATCH 0004 / 0011 | LOSS 0.0747
# TRAIN: EPOCH 0024 / 0100 | BATCH 0005 / 0011 | LOSS 0.0914
# TRAIN: EPOCH 0024 / 0100 | BATCH 0006 / 0011 | LOSS 0.0834
# TRAIN: EPOCH 0024 / 0100 | BATCH 0007 / 0011 | LOSS 0.0845
# TRAIN: EPOCH 0024 / 0100 | BATCH 0008 / 0011 | LOSS 0.0802
# TRAIN: EPOCH 0024 / 0100 | BATCH 0009 / 0011 | LOSS 0.0780
# TRAIN: EPOCH 0024 / 0100 | BATCH 0010 / 0011 | LOSS 0.0763
# TRAIN: EPOCH 0024 / 0100 | BATCH 0011 / 0011 | LOSS 0.0745
# TRAIN: EPOCH 0025 / 0100 | BATCH 0001 / 0011 | LOSS 0.0517
# TRAIN: EPOCH 0025 / 0100 | BATCH 0002 / 0011 | LOSS 0.0693
# TRAIN: EPOCH 0025 / 0100 | BATCH 0003 / 0011 | LOSS 0.0685
# TRAIN: EPOCH 0025 / 0100 | BATCH 0004 / 0011 | LOSS 0.0659
# TRAIN: EPOCH 0025 / 0100 | BATCH 0005 / 0011 | LOSS 0.0734
# TRAIN: EPOCH 0025 / 0100 | BATCH 0006 / 0011 | LOSS 0.0694
# TRAIN: EPOCH 0025 / 0100 | BATCH 0007 / 0011 | LOSS 0.0666
# TRAIN: EPOCH 0025 / 0100 | BATCH 0008 / 0011 | LOSS 0.0652
# TRAIN: EPOCH 0025 / 0100 | BATCH 0009 / 0011 | LOSS 0.0630
# TRAIN: EPOCH 0025 / 0100 | BATCH 0010 / 0011 | LOSS 0.0734
# TRAIN: EPOCH 0025 / 0100 | BATCH 0011 / 0011 | LOSS 0.0792
# TRAIN: EPOCH 0026 / 0100 | BATCH 0001 / 0011 | LOSS 0.0711
# TRAIN: EPOCH 0026 / 0100 | BATCH 0002 / 0011 | LOSS 0.0826
# TRAIN: EPOCH 0026 / 0100 | BATCH 0003 / 0011 | LOSS 0.0802
# TRAIN: EPOCH 0026 / 0100 | BATCH 0004 / 0011 | LOSS 0.0740
# TRAIN: EPOCH 0026 / 0100 | BATCH 0005 / 0011 | LOSS 0.0758
# TRAIN: EPOCH 0026 / 0100 | BATCH 0006 / 0011 | LOSS 0.0793
# TRAIN: EPOCH 0026 / 0100 | BATCH 0007 / 0011 | LOSS 0.0760
# TRAIN: EPOCH 0026 / 0100 | BATCH 0008 / 0011 | LOSS 0.0747
# TRAIN: EPOCH 0026 / 0100 | BATCH 0009 / 0011 | LOSS 0.0721
# TRAIN: EPOCH 0026 / 0100 | BATCH 0010 / 0011 | LOSS 0.0705
# TRAIN: EPOCH 0026 / 0100 | BATCH 0011 / 0011 | LOSS 0.0798
# TRAIN: EPOCH 0027 / 0100 | BATCH 0001 / 0011 | LOSS 0.0515
# TRAIN: EPOCH 0027 / 0100 | BATCH 0002 / 0011 | LOSS 0.0586
# TRAIN: EPOCH 0027 / 0100 | BATCH 0003 / 0011 | LOSS 0.0744
# TRAIN: EPOCH 0027 / 0100 | BATCH 0004 / 0011 | LOSS 0.0716
# TRAIN: EPOCH 0027 / 0100 | BATCH 0005 / 0011 | LOSS 0.0671
# TRAIN: EPOCH 0027 / 0100 | BATCH 0006 / 0011 | LOSS 0.0784
# TRAIN: EPOCH 0027 / 0100 | BATCH 0007 / 0011 | LOSS 0.0788
# TRAIN: EPOCH 0027 / 0100 | BATCH 0008 / 0011 | LOSS 0.0760
# TRAIN: EPOCH 0027 / 0100 | BATCH 0009 / 0011 | LOSS 0.0747
# TRAIN: EPOCH 0027 / 0100 | BATCH 0010 / 0011 | LOSS 0.0724
# TRAIN: EPOCH 0027 / 0100 | BATCH 0011 / 0011 | LOSS 0.0733
# TRAIN: EPOCH 0028 / 0100 | BATCH 0001 / 0011 | LOSS 0.0808
# TRAIN: EPOCH 0028 / 0100 | BATCH 0002 / 0011 | LOSS 0.0764
# TRAIN: EPOCH 0028 / 0100 | BATCH 0003 / 0011 | LOSS 0.0686
# TRAIN: EPOCH 0028 / 0100 | BATCH 0004 / 0011 | LOSS 0.0737
# TRAIN: EPOCH 0028 / 0100 | BATCH 0005 / 0011 | LOSS 0.0685
# TRAIN: EPOCH 0028 / 0100 | BATCH 0006 / 0011 | LOSS 0.0650
# TRAIN: EPOCH 0028 / 0100 | BATCH 0007 / 0011 | LOSS 0.0629
# TRAIN: EPOCH 0028 / 0100 | BATCH 0008 / 0011 | LOSS 0.0681
# TRAIN: EPOCH 0028 / 0100 | BATCH 0009 / 0011 | LOSS 0.0694
# TRAIN: EPOCH 0028 / 0100 | BATCH 0010 / 0011 | LOSS 0.0664
# TRAIN: EPOCH 0028 / 0100 | BATCH 0011 / 0011 | LOSS 0.0747
# TRAIN: EPOCH 0029 / 0100 | BATCH 0001 / 0011 | LOSS 0.0649
# TRAIN: EPOCH 0029 / 0100 | BATCH 0002 / 0011 | LOSS 0.0587
# TRAIN: EPOCH 0029 / 0100 | BATCH 0003 / 0011 | LOSS 0.0702
# TRAIN: EPOCH 0029 / 0100 | BATCH 0004 / 0011 | LOSS 0.0653
# TRAIN: EPOCH 0029 / 0100 | BATCH 0005 / 0011 | LOSS 0.0606
# TRAIN: EPOCH 0029 / 0100 | BATCH 0006 / 0011 | LOSS 0.0580
# TRAIN: EPOCH 0029 / 0100 | BATCH 0007 / 0011 | LOSS 0.0744
# TRAIN: EPOCH 0029 / 0100 | BATCH 0008 / 0011 | LOSS 0.0762
# TRAIN: EPOCH 0029 / 0100 | BATCH 0009 / 0011 | LOSS 0.0724
# TRAIN: EPOCH 0029 / 0100 | BATCH 0010 / 0011 | LOSS 0.0699
# TRAIN: EPOCH 0029 / 0100 | BATCH 0011 / 0011 | LOSS 0.0688
# TRAIN: EPOCH 0030 / 0100 | BATCH 0001 / 0011 | LOSS 0.0474
# TRAIN: EPOCH 0030 / 0100 | BATCH 0002 / 0011 | LOSS 0.0582
# TRAIN: EPOCH 0030 / 0100 | BATCH 0003 / 0011 | LOSS 0.0556
# TRAIN: EPOCH 0030 / 0100 | BATCH 0004 / 0011 | LOSS 0.0610
# TRAIN: EPOCH 0030 / 0100 | BATCH 0005 / 0011 | LOSS 0.0565
# TRAIN: EPOCH 0030 / 0100 | BATCH 0006 / 0011 | LOSS 0.0535
# TRAIN: EPOCH 0030 / 0100 | BATCH 0007 / 0011 | LOSS 0.0524
# TRAIN: EPOCH 0030 / 0100 | BATCH 0008 / 0011 | LOSS 0.0591
# TRAIN: EPOCH 0030 / 0100 | BATCH 0009 / 0011 | LOSS 0.0642
# TRAIN: EPOCH 0030 / 0100 | BATCH 0010 / 0011 | LOSS 0.0679
# TRAIN: EPOCH 0030 / 0100 | BATCH 0011 / 0011 | LOSS 0.0645
# TRAIN: EPOCH 0031 / 0100 | BATCH 0001 / 0011 | LOSS 0.0413
# TRAIN: EPOCH 0031 / 0100 | BATCH 0002 / 0011 | LOSS 0.0361
# TRAIN: EPOCH 0031 / 0100 | BATCH 0003 / 0011 | LOSS 0.0394
# TRAIN: EPOCH 0031 / 0100 | BATCH 0004 / 0011 | LOSS 0.0423
# TRAIN: EPOCH 0031 / 0100 | BATCH 0005 / 0011 | LOSS 0.0558
# TRAIN: EPOCH 0031 / 0100 | BATCH 0006 / 0011 | LOSS 0.0641
# TRAIN: EPOCH 0031 / 0100 | BATCH 0007 / 0011 | LOSS 0.0680
# TRAIN: EPOCH 0031 / 0100 | BATCH 0008 / 0011 | LOSS 0.0651
# TRAIN: EPOCH 0031 / 0100 | BATCH 0009 / 0011 | LOSS 0.0693
# TRAIN: EPOCH 0031 / 0100 | BATCH 0010 / 0011 | LOSS 0.0669
# TRAIN: EPOCH 0031 / 0100 | BATCH 0011 / 0011 | LOSS 0.0663
# TRAIN: EPOCH 0032 / 0100 | BATCH 0001 / 0011 | LOSS 0.0375
# TRAIN: EPOCH 0032 / 0100 | BATCH 0002 / 0011 | LOSS 0.0399
# TRAIN: EPOCH 0032 / 0100 | BATCH 0003 / 0011 | LOSS 0.0438
# TRAIN: EPOCH 0032 / 0100 | BATCH 0004 / 0011 | LOSS 0.0436
# TRAIN: EPOCH 0032 / 0100 | BATCH 0005 / 0011 | LOSS 0.0446
# TRAIN: EPOCH 0032 / 0100 | BATCH 0006 / 0011 | LOSS 0.0543
# TRAIN: EPOCH 0032 / 0100 | BATCH 0007 / 0011 | LOSS 0.0613
# TRAIN: EPOCH 0032 / 0100 | BATCH 0008 / 0011 | LOSS 0.0674
# TRAIN: EPOCH 0032 / 0100 | BATCH 0009 / 0011 | LOSS 0.0641
# TRAIN: EPOCH 0032 / 0100 | BATCH 0010 / 0011 | LOSS 0.0619
# TRAIN: EPOCH 0032 / 0100 | BATCH 0011 / 0011 | LOSS 0.0700
# TRAIN: EPOCH 0033 / 0100 | BATCH 0001 / 0011 | LOSS 0.0399
# TRAIN: EPOCH 0033 / 0100 | BATCH 0002 / 0011 | LOSS 0.0632
# TRAIN: EPOCH 0033 / 0100 | BATCH 0003 / 0011 | LOSS 0.0798
# TRAIN: EPOCH 0033 / 0100 | BATCH 0004 / 0011 | LOSS 0.0737
# TRAIN: EPOCH 0033 / 0100 | BATCH 0005 / 0011 | LOSS 0.0663
# TRAIN: EPOCH 0033 / 0100 | BATCH 0006 / 0011 | LOSS 0.0695
# TRAIN: EPOCH 0033 / 0100 | BATCH 0007 / 0011 | LOSS 0.0728
# TRAIN: EPOCH 0033 / 0100 | BATCH 0008 / 0011 | LOSS 0.0715
# TRAIN: EPOCH 0033 / 0100 | BATCH 0009 / 0011 | LOSS 0.0735
# TRAIN: EPOCH 0033 / 0100 | BATCH 0010 / 0011 | LOSS 0.0732
# TRAIN: EPOCH 0033 / 0100 | BATCH 0011 / 0011 | LOSS 0.0719
# TRAIN: EPOCH 0034 / 0100 | BATCH 0001 / 0011 | LOSS 0.0515
# TRAIN: EPOCH 0034 / 0100 | BATCH 0002 / 0011 | LOSS 0.0571
# TRAIN: EPOCH 0034 / 0100 | BATCH 0003 / 0011 | LOSS 0.0554
# TRAIN: EPOCH 0034 / 0100 | BATCH 0004 / 0011 | LOSS 0.0842
# TRAIN: EPOCH 0034 / 0100 | BATCH 0005 / 0011 | LOSS 0.0857
# TRAIN: EPOCH 0034 / 0100 | BATCH 0006 / 0011 | LOSS 0.0775
# TRAIN: EPOCH 0034 / 0100 | BATCH 0007 / 0011 | LOSS 0.0791
# TRAIN: EPOCH 0034 / 0100 | BATCH 0008 / 0011 | LOSS 0.0748
# TRAIN: EPOCH 0034 / 0100 | BATCH 0009 / 0011 | LOSS 0.0749
# TRAIN: EPOCH 0034 / 0100 | BATCH 0010 / 0011 | LOSS 0.0742
# TRAIN: EPOCH 0034 / 0100 | BATCH 0011 / 0011 | LOSS 0.0730
# TRAIN: EPOCH 0035 / 0100 | BATCH 0001 / 0011 | LOSS 0.0493
# TRAIN: EPOCH 0035 / 0100 | BATCH 0002 / 0011 | LOSS 0.0794
# TRAIN: EPOCH 0035 / 0100 | BATCH 0003 / 0011 | LOSS 0.0760
# TRAIN: EPOCH 0035 / 0100 | BATCH 0004 / 0011 | LOSS 0.0669
# TRAIN: EPOCH 0035 / 0100 | BATCH 0005 / 0011 | LOSS 0.0733
# TRAIN: EPOCH 0035 / 0100 | BATCH 0006 / 0011 | LOSS 0.0706
# TRAIN: EPOCH 0035 / 0100 | BATCH 0007 / 0011 | LOSS 0.0678
# TRAIN: EPOCH 0035 / 0100 | BATCH 0008 / 0011 | LOSS 0.0703
# TRAIN: EPOCH 0035 / 0100 | BATCH 0009 / 0011 | LOSS 0.0668
# TRAIN: EPOCH 0035 / 0100 | BATCH 0010 / 0011 | LOSS 0.0694
# TRAIN: EPOCH 0035 / 0100 | BATCH 0011 / 0011 | LOSS 0.0667
# TRAIN: EPOCH 0036 / 0100 | BATCH 0001 / 0011 | LOSS 0.0462
# TRAIN: EPOCH 0036 / 0100 | BATCH 0002 / 0011 | LOSS 0.0444
# TRAIN: EPOCH 0036 / 0100 | BATCH 0003 / 0011 | LOSS 0.0425
# TRAIN: EPOCH 0036 / 0100 | BATCH 0004 / 0011 | LOSS 0.0483
# TRAIN: EPOCH 0036 / 0100 | BATCH 0005 / 0011 | LOSS 0.0466
# TRAIN: EPOCH 0036 / 0100 | BATCH 0006 / 0011 | LOSS 0.0517
# TRAIN: EPOCH 0036 / 0100 | BATCH 0007 / 0011 | LOSS 0.0498
# TRAIN: EPOCH 0036 / 0100 | BATCH 0008 / 0011 | LOSS 0.0570
# TRAIN: EPOCH 0036 / 0100 | BATCH 0009 / 0011 | LOSS 0.0647
# TRAIN: EPOCH 0036 / 0100 | BATCH 0010 / 0011 | LOSS 0.0692
# TRAIN: EPOCH 0036 / 0100 | BATCH 0011 / 0011 | LOSS 0.0660
# TRAIN: EPOCH 0037 / 0100 | BATCH 0001 / 0011 | LOSS 0.0378
# TRAIN: EPOCH 0037 / 0100 | BATCH 0002 / 0011 | LOSS 0.0424
# TRAIN: EPOCH 0037 / 0100 | BATCH 0003 / 0011 | LOSS 0.0467
# TRAIN: EPOCH 0037 / 0100 | BATCH 0004 / 0011 | LOSS 0.0455
# TRAIN: EPOCH 0037 / 0100 | BATCH 0005 / 0011 | LOSS 0.0436
# TRAIN: EPOCH 0037 / 0100 | BATCH 0006 / 0011 | LOSS 0.0424
# TRAIN: EPOCH 0037 / 0100 | BATCH 0007 / 0011 | LOSS 0.0497
# TRAIN: EPOCH 0037 / 0100 | BATCH 0008 / 0011 | LOSS 0.0582
# TRAIN: EPOCH 0037 / 0100 | BATCH 0009 / 0011 | LOSS 0.0629
# TRAIN: EPOCH 0037 / 0100 | BATCH 0010 / 0011 | LOSS 0.0606
# TRAIN: EPOCH 0037 / 0100 | BATCH 0011 / 0011 | LOSS 0.0691
# TRAIN: EPOCH 0038 / 0100 | BATCH 0001 / 0011 | LOSS 0.0316
# TRAIN: EPOCH 0038 / 0100 | BATCH 0002 / 0011 | LOSS 0.0403
# TRAIN: EPOCH 0038 / 0100 | BATCH 0003 / 0011 | LOSS 0.0572
# TRAIN: EPOCH 0038 / 0100 | BATCH 0004 / 0011 | LOSS 0.0546
# TRAIN: EPOCH 0038 / 0100 | BATCH 0005 / 0011 | LOSS 0.0594
# TRAIN: EPOCH 0038 / 0100 | BATCH 0006 / 0011 | LOSS 0.0573
# TRAIN: EPOCH 0038 / 0100 | BATCH 0007 / 0011 | LOSS 0.0645
# TRAIN: EPOCH 0038 / 0100 | BATCH 0008 / 0011 | LOSS 0.0695
# TRAIN: EPOCH 0038 / 0100 | BATCH 0009 / 0011 | LOSS 0.0659
# TRAIN: EPOCH 0038 / 0100 | BATCH 0010 / 0011 | LOSS 0.0640
# TRAIN: EPOCH 0038 / 0100 | BATCH 0011 / 0011 | LOSS 0.0717
# TRAIN: EPOCH 0039 / 0100 | BATCH 0001 / 0011 | LOSS 0.0429
# TRAIN: EPOCH 0039 / 0100 | BATCH 0002 / 0011 | LOSS 0.0527
# TRAIN: EPOCH 0039 / 0100 | BATCH 0003 / 0011 | LOSS 0.0715
# TRAIN: EPOCH 0039 / 0100 | BATCH 0004 / 0011 | LOSS 0.0760
# TRAIN: EPOCH 0039 / 0100 | BATCH 0005 / 0011 | LOSS 0.0900
# TRAIN: EPOCH 0039 / 0100 | BATCH 0006 / 0011 | LOSS 0.0866
# TRAIN: EPOCH 0039 / 0100 | BATCH 0007 / 0011 | LOSS 0.0809
# TRAIN: EPOCH 0039 / 0100 | BATCH 0008 / 0011 | LOSS 0.0784
# TRAIN: EPOCH 0039 / 0100 | BATCH 0009 / 0011 | LOSS 0.0847
# TRAIN: EPOCH 0039 / 0100 | BATCH 0010 / 0011 | LOSS 0.0835
# TRAIN: EPOCH 0039 / 0100 | BATCH 0011 / 0011 | LOSS 0.0812
# TRAIN: EPOCH 0040 / 0100 | BATCH 0001 / 0011 | LOSS 0.0626
# TRAIN: EPOCH 0040 / 0100 | BATCH 0002 / 0011 | LOSS 0.0889
# TRAIN: EPOCH 0040 / 0100 | BATCH 0003 / 0011 | LOSS 0.0880
# TRAIN: EPOCH 0040 / 0100 | BATCH 0004 / 0011 | LOSS 0.0805
# TRAIN: EPOCH 0040 / 0100 | BATCH 0005 / 0011 | LOSS 0.0802
# TRAIN: EPOCH 0040 / 0100 | BATCH 0006 / 0011 | LOSS 0.0765
# TRAIN: EPOCH 0040 / 0100 | BATCH 0007 / 0011 | LOSS 0.0778
# TRAIN: EPOCH 0040 / 0100 | BATCH 0008 / 0011 | LOSS 0.0728
# TRAIN: EPOCH 0040 / 0100 | BATCH 0009 / 0011 | LOSS 0.0731
# TRAIN: EPOCH 0040 / 0100 | BATCH 0010 / 0011 | LOSS 0.0701
# TRAIN: EPOCH 0040 / 0100 | BATCH 0011 / 0011 | LOSS 0.0683
# TRAIN: EPOCH 0041 / 0100 | BATCH 0001 / 0011 | LOSS 0.0769
# TRAIN: EPOCH 0041 / 0100 | BATCH 0002 / 0011 | LOSS 0.0737
# TRAIN: EPOCH 0041 / 0100 | BATCH 0003 / 0011 | LOSS 0.0696
# TRAIN: EPOCH 0041 / 0100 | BATCH 0004 / 0011 | LOSS 0.0635
# TRAIN: EPOCH 0041 / 0100 | BATCH 0005 / 0011 | LOSS 0.0604
# TRAIN: EPOCH 0041 / 0100 | BATCH 0006 / 0011 | LOSS 0.0669
# TRAIN: EPOCH 0041 / 0100 | BATCH 0007 / 0011 | LOSS 0.0738
# TRAIN: EPOCH 0041 / 0100 | BATCH 0008 / 0011 | LOSS 0.0701
# TRAIN: EPOCH 0041 / 0100 | BATCH 0009 / 0011 | LOSS 0.0708
# TRAIN: EPOCH 0041 / 0100 | BATCH 0010 / 0011 | LOSS 0.0677
# TRAIN: EPOCH 0041 / 0100 | BATCH 0011 / 0011 | LOSS 0.0654
# TRAIN: EPOCH 0042 / 0100 | BATCH 0001 / 0011 | LOSS 0.0487
# TRAIN: EPOCH 0042 / 0100 | BATCH 0002 / 0011 | LOSS 0.0523
# TRAIN: EPOCH 0042 / 0100 | BATCH 0003 / 0011 | LOSS 0.0601
# TRAIN: EPOCH 0042 / 0100 | BATCH 0004 / 0011 | LOSS 0.0743
# TRAIN: EPOCH 0042 / 0100 | BATCH 0005 / 0011 | LOSS 0.0804
# TRAIN: EPOCH 0042 / 0100 | BATCH 0006 / 0011 | LOSS 0.0808
# TRAIN: EPOCH 0042 / 0100 | BATCH 0007 / 0011 | LOSS 0.0749
# TRAIN: EPOCH 0042 / 0100 | BATCH 0008 / 0011 | LOSS 0.0711
# TRAIN: EPOCH 0042 / 0100 | BATCH 0009 / 0011 | LOSS 0.0674
# TRAIN: EPOCH 0042 / 0100 | BATCH 0010 / 0011 | LOSS 0.0653
# TRAIN: EPOCH 0042 / 0100 | BATCH 0011 / 0011 | LOSS 0.0626
# TRAIN: EPOCH 0043 / 0100 | BATCH 0001 / 0011 | LOSS 0.1097
# TRAIN: EPOCH 0043 / 0100 | BATCH 0002 / 0011 | LOSS 0.1359
# TRAIN: EPOCH 0043 / 0100 | BATCH 0003 / 0011 | LOSS 0.1049
# TRAIN: EPOCH 0043 / 0100 | BATCH 0004 / 0011 | LOSS 0.0887
# TRAIN: EPOCH 0043 / 0100 | BATCH 0005 / 0011 | LOSS 0.0791
# TRAIN: EPOCH 0043 / 0100 | BATCH 0006 / 0011 | LOSS 0.0709
# TRAIN: EPOCH 0043 / 0100 | BATCH 0007 / 0011 | LOSS 0.0735
# TRAIN: EPOCH 0043 / 0100 | BATCH 0008 / 0011 | LOSS 0.0719
# TRAIN: EPOCH 0043 / 0100 | BATCH 0009 / 0011 | LOSS 0.0716
# TRAIN: EPOCH 0043 / 0100 | BATCH 0010 / 0011 | LOSS 0.0684
# TRAIN: EPOCH 0043 / 0100 | BATCH 0011 / 0011 | LOSS 0.0655
# TRAIN: EPOCH 0044 / 0100 | BATCH 0001 / 0011 | LOSS 0.0785
# TRAIN: EPOCH 0044 / 0100 | BATCH 0002 / 0011 | LOSS 0.0865
# TRAIN: EPOCH 0044 / 0100 | BATCH 0003 / 0011 | LOSS 0.0938
# TRAIN: EPOCH 0044 / 0100 | BATCH 0004 / 0011 | LOSS 0.0822
# TRAIN: EPOCH 0044 / 0100 | BATCH 0005 / 0011 | LOSS 0.0776
# TRAIN: EPOCH 0044 / 0100 | BATCH 0006 / 0011 | LOSS 0.0798
# TRAIN: EPOCH 0044 / 0100 | BATCH 0007 / 0011 | LOSS 0.0741
# TRAIN: EPOCH 0044 / 0100 | BATCH 0008 / 0011 | LOSS 0.0719
# TRAIN: EPOCH 0044 / 0100 | BATCH 0009 / 0011 | LOSS 0.0696
# TRAIN: EPOCH 0044 / 0100 | BATCH 0010 / 0011 | LOSS 0.0663
# TRAIN: EPOCH 0044 / 0100 | BATCH 0011 / 0011 | LOSS 0.0633
# TRAIN: EPOCH 0045 / 0100 | BATCH 0001 / 0011 | LOSS 0.0356
# TRAIN: EPOCH 0045 / 0100 | BATCH 0002 / 0011 | LOSS 0.0373
# TRAIN: EPOCH 0045 / 0100 | BATCH 0003 / 0011 | LOSS 0.0404
# TRAIN: EPOCH 0045 / 0100 | BATCH 0004 / 0011 | LOSS 0.0394
# TRAIN: EPOCH 0045 / 0100 | BATCH 0005 / 0011 | LOSS 0.0474
# TRAIN: EPOCH 0045 / 0100 | BATCH 0006 / 0011 | LOSS 0.0450
# TRAIN: EPOCH 0045 / 0100 | BATCH 0007 / 0011 | LOSS 0.0638
# TRAIN: EPOCH 0045 / 0100 | BATCH 0008 / 0011 | LOSS 0.0619
# TRAIN: EPOCH 0045 / 0100 | BATCH 0009 / 0011 | LOSS 0.0605
# TRAIN: EPOCH 0045 / 0100 | BATCH 0010 / 0011 | LOSS 0.0579
# TRAIN: EPOCH 0045 / 0100 | BATCH 0011 / 0011 | LOSS 0.0711
# TRAIN: EPOCH 0046 / 0100 | BATCH 0001 / 0011 | LOSS 0.0509
# TRAIN: EPOCH 0046 / 0100 | BATCH 0002 / 0011 | LOSS 0.0695
# TRAIN: EPOCH 0046 / 0100 | BATCH 0003 / 0011 | LOSS 0.0824
# TRAIN: EPOCH 0046 / 0100 | BATCH 0004 / 0011 | LOSS 0.0860
# TRAIN: EPOCH 0046 / 0100 | BATCH 0005 / 0011 | LOSS 0.0852
# TRAIN: EPOCH 0046 / 0100 | BATCH 0006 / 0011 | LOSS 0.0811
# TRAIN: EPOCH 0046 / 0100 | BATCH 0007 / 0011 | LOSS 0.0752
# TRAIN: EPOCH 0046 / 0100 | BATCH 0008 / 0011 | LOSS 0.0703
# TRAIN: EPOCH 0046 / 0100 | BATCH 0009 / 0011 | LOSS 0.0677
# TRAIN: EPOCH 0046 / 0100 | BATCH 0010 / 0011 | LOSS 0.0656
# TRAIN: EPOCH 0046 / 0100 | BATCH 0011 / 0011 | LOSS 0.0630
# TRAIN: EPOCH 0047 / 0100 | BATCH 0001 / 0011 | LOSS 0.0420
# TRAIN: EPOCH 0047 / 0100 | BATCH 0002 / 0011 | LOSS 0.0672
# TRAIN: EPOCH 0047 / 0100 | BATCH 0003 / 0011 | LOSS 0.0881
# TRAIN: EPOCH 0047 / 0100 | BATCH 0004 / 0011 | LOSS 0.0832
# TRAIN: EPOCH 0047 / 0100 | BATCH 0005 / 0011 | LOSS 0.0767
# TRAIN: EPOCH 0047 / 0100 | BATCH 0006 / 0011 | LOSS 0.0702
# TRAIN: EPOCH 0047 / 0100 | BATCH 0007 / 0011 | LOSS 0.0659
# TRAIN: EPOCH 0047 / 0100 | BATCH 0008 / 0011 | LOSS 0.0642
# TRAIN: EPOCH 0047 / 0100 | BATCH 0009 / 0011 | LOSS 0.0687
# TRAIN: EPOCH 0047 / 0100 | BATCH 0010 / 0011 | LOSS 0.0660
# TRAIN: EPOCH 0047 / 0100 | BATCH 0011 / 0011 | LOSS 0.0643
# TRAIN: EPOCH 0048 / 0100 | BATCH 0001 / 0011 | LOSS 0.0545
# TRAIN: EPOCH 0048 / 0100 | BATCH 0002 / 0011 | LOSS 0.0687
# TRAIN: EPOCH 0048 / 0100 | BATCH 0003 / 0011 | LOSS 0.0602
# TRAIN: EPOCH 0048 / 0100 | BATCH 0004 / 0011 | LOSS 0.0682
# TRAIN: EPOCH 0048 / 0100 | BATCH 0005 / 0011 | LOSS 0.0635
# TRAIN: EPOCH 0048 / 0100 | BATCH 0006 / 0011 | LOSS 0.0589
# TRAIN: EPOCH 0048 / 0100 | BATCH 0007 / 0011 | LOSS 0.0565
# TRAIN: EPOCH 0048 / 0100 | BATCH 0008 / 0011 | LOSS 0.0541
# TRAIN: EPOCH 0048 / 0100 | BATCH 0009 / 0011 | LOSS 0.0515
# TRAIN: EPOCH 0048 / 0100 | BATCH 0010 / 0011 | LOSS 0.0539
# TRAIN: EPOCH 0048 / 0100 | BATCH 0011 / 0011 | LOSS 0.0662
# TRAIN: EPOCH 0049 / 0100 | BATCH 0001 / 0011 | LOSS 0.0995
# TRAIN: EPOCH 0049 / 0100 | BATCH 0002 / 0011 | LOSS 0.0801
# TRAIN: EPOCH 0049 / 0100 | BATCH 0003 / 0011 | LOSS 0.0769
# TRAIN: EPOCH 0049 / 0100 | BATCH 0004 / 0011 | LOSS 0.0721
# TRAIN: EPOCH 0049 / 0100 | BATCH 0005 / 0011 | LOSS 0.0640
# TRAIN: EPOCH 0049 / 0100 | BATCH 0006 / 0011 | LOSS 0.0608
# TRAIN: EPOCH 0049 / 0100 | BATCH 0007 / 0011 | LOSS 0.0663
# TRAIN: EPOCH 0049 / 0100 | BATCH 0008 / 0011 | LOSS 0.0627
# TRAIN: EPOCH 0049 / 0100 | BATCH 0009 / 0011 | LOSS 0.0598
# TRAIN: EPOCH 0049 / 0100 | BATCH 0010 / 0011 | LOSS 0.0634
# TRAIN: EPOCH 0049 / 0100 | BATCH 0011 / 0011 | LOSS 0.0609
# TRAIN: EPOCH 0050 / 0100 | BATCH 0001 / 0011 | LOSS 0.0708
# TRAIN: EPOCH 0050 / 0100 | BATCH 0002 / 0011 | LOSS 0.0570
# TRAIN: EPOCH 0050 / 0100 | BATCH 0003 / 0011 | LOSS 0.0512
# TRAIN: EPOCH 0050 / 0100 | BATCH 0004 / 0011 | LOSS 0.0638
# TRAIN: EPOCH 0050 / 0100 | BATCH 0005 / 0011 | LOSS 0.0595
# TRAIN: EPOCH 0050 / 0100 | BATCH 0006 / 0011 | LOSS 0.0569
# TRAIN: EPOCH 0050 / 0100 | BATCH 0007 / 0011 | LOSS 0.0613
# TRAIN: EPOCH 0050 / 0100 | BATCH 0008 / 0011 | LOSS 0.0601
# TRAIN: EPOCH 0050 / 0100 | BATCH 0009 / 0011 | LOSS 0.0576
# TRAIN: EPOCH 0050 / 0100 | BATCH 0010 / 0011 | LOSS 0.0600
# TRAIN: EPOCH 0050 / 0100 | BATCH 0011 / 0011 | LOSS 0.0590
# TRAIN: EPOCH 0051 / 0100 | BATCH 0001 / 0011 | LOSS 0.0420
# TRAIN: EPOCH 0051 / 0100 | BATCH 0002 / 0011 | LOSS 0.0702
# TRAIN: EPOCH 0051 / 0100 | BATCH 0003 / 0011 | LOSS 0.0584
# TRAIN: EPOCH 0051 / 0100 | BATCH 0004 / 0011 | LOSS 0.0532
# TRAIN: EPOCH 0051 / 0100 | BATCH 0005 / 0011 | LOSS 0.0594
# TRAIN: EPOCH 0051 / 0100 | BATCH 0006 / 0011 | LOSS 0.0613
# TRAIN: EPOCH 0051 / 0100 | BATCH 0007 / 0011 | LOSS 0.0590
# TRAIN: EPOCH 0051 / 0100 | BATCH 0008 / 0011 | LOSS 0.0626
# TRAIN: EPOCH 0051 / 0100 | BATCH 0009 / 0011 | LOSS 0.0646
# TRAIN: EPOCH 0051 / 0100 | BATCH 0010 / 0011 | LOSS 0.0614
# TRAIN: EPOCH 0051 / 0100 | BATCH 0011 / 0011 | LOSS 0.0594
# TRAIN: EPOCH 0052 / 0100 | BATCH 0001 / 0011 | LOSS 0.0769
# TRAIN: EPOCH 0052 / 0100 | BATCH 0002 / 0011 | LOSS 0.0542
# TRAIN: EPOCH 0052 / 0100 | BATCH 0003 / 0011 | LOSS 0.0465
# TRAIN: EPOCH 0052 / 0100 | BATCH 0004 / 0011 | LOSS 0.0590
# TRAIN: EPOCH 0052 / 0100 | BATCH 0005 / 0011 | LOSS 0.0556
# TRAIN: EPOCH 0052 / 0100 | BATCH 0006 / 0011 | LOSS 0.0552
# TRAIN: EPOCH 0052 / 0100 | BATCH 0007 / 0011 | LOSS 0.0537
# TRAIN: EPOCH 0052 / 0100 | BATCH 0008 / 0011 | LOSS 0.0607
# TRAIN: EPOCH 0052 / 0100 | BATCH 0009 / 0011 | LOSS 0.0577
# TRAIN: EPOCH 0052 / 0100 | BATCH 0010 / 0011 | LOSS 0.0616
# TRAIN: EPOCH 0052 / 0100 | BATCH 0011 / 0011 | LOSS 0.0595
# TRAIN: EPOCH 0053 / 0100 | BATCH 0001 / 0011 | LOSS 0.0485
# TRAIN: EPOCH 0053 / 0100 | BATCH 0002 / 0011 | LOSS 0.0785
# TRAIN: EPOCH 0053 / 0100 | BATCH 0003 / 0011 | LOSS 0.0641
# TRAIN: EPOCH 0053 / 0100 | BATCH 0004 / 0011 | LOSS 0.0564
# TRAIN: EPOCH 0053 / 0100 | BATCH 0005 / 0011 | LOSS 0.0518
# TRAIN: EPOCH 0053 / 0100 | BATCH 0006 / 0011 | LOSS 0.0698
# TRAIN: EPOCH 0053 / 0100 | BATCH 0007 / 0011 | LOSS 0.0648
# TRAIN: EPOCH 0053 / 0100 | BATCH 0008 / 0011 | LOSS 0.0666
# TRAIN: EPOCH 0053 / 0100 | BATCH 0009 / 0011 | LOSS 0.0634
# TRAIN: EPOCH 0053 / 0100 | BATCH 0010 / 0011 | LOSS 0.0621
# TRAIN: EPOCH 0053 / 0100 | BATCH 0011 / 0011 | LOSS 0.0593
# TRAIN: EPOCH 0054 / 0100 | BATCH 0001 / 0011 | LOSS 0.0328
# TRAIN: EPOCH 0054 / 0100 | BATCH 0002 / 0011 | LOSS 0.0324
# TRAIN: EPOCH 0054 / 0100 | BATCH 0003 / 0011 | LOSS 0.0559
# TRAIN: EPOCH 0054 / 0100 | BATCH 0004 / 0011 | LOSS 0.0523
# TRAIN: EPOCH 0054 / 0100 | BATCH 0005 / 0011 | LOSS 0.0499
# TRAIN: EPOCH 0054 / 0100 | BATCH 0006 / 0011 | LOSS 0.0463
# TRAIN: EPOCH 0054 / 0100 | BATCH 0007 / 0011 | LOSS 0.0463
# TRAIN: EPOCH 0054 / 0100 | BATCH 0008 / 0011 | LOSS 0.0500
# TRAIN: EPOCH 0054 / 0100 | BATCH 0009 / 0011 | LOSS 0.0568
# TRAIN: EPOCH 0054 / 0100 | BATCH 0010 / 0011 | LOSS 0.0597
# TRAIN: EPOCH 0054 / 0100 | BATCH 0011 / 0011 | LOSS 0.0576
# TRAIN: EPOCH 0055 / 0100 | BATCH 0001 / 0011 | LOSS 0.0421
# TRAIN: EPOCH 0055 / 0100 | BATCH 0002 / 0011 | LOSS 0.0368
# TRAIN: EPOCH 0055 / 0100 | BATCH 0003 / 0011 | LOSS 0.0596
# TRAIN: EPOCH 0055 / 0100 | BATCH 0004 / 0011 | LOSS 0.0657
# TRAIN: EPOCH 0055 / 0100 | BATCH 0005 / 0011 | LOSS 0.0594
# TRAIN: EPOCH 0055 / 0100 | BATCH 0006 / 0011 | LOSS 0.0614
# TRAIN: EPOCH 0055 / 0100 | BATCH 0007 / 0011 | LOSS 0.0588
# TRAIN: EPOCH 0055 / 0100 | BATCH 0008 / 0011 | LOSS 0.0556
# TRAIN: EPOCH 0055 / 0100 | BATCH 0009 / 0011 | LOSS 0.0596
# TRAIN: EPOCH 0055 / 0100 | BATCH 0010 / 0011 | LOSS 0.0601
# TRAIN: EPOCH 0055 / 0100 | BATCH 0011 / 0011 | LOSS 0.0586
# TRAIN: EPOCH 0056 / 0100 | BATCH 0001 / 0011 | LOSS 0.0435
# TRAIN: EPOCH 0056 / 0100 | BATCH 0002 / 0011 | LOSS 0.0618
# TRAIN: EPOCH 0056 / 0100 | BATCH 0003 / 0011 | LOSS 0.0522
# TRAIN: EPOCH 0056 / 0100 | BATCH 0004 / 0011 | LOSS 0.0650
# TRAIN: EPOCH 0056 / 0100 | BATCH 0005 / 0011 | LOSS 0.0585
# TRAIN: EPOCH 0056 / 0100 | BATCH 0006 / 0011 | LOSS 0.0737
# TRAIN: EPOCH 0056 / 0100 | BATCH 0007 / 0011 | LOSS 0.0701
# TRAIN: EPOCH 0056 / 0100 | BATCH 0008 / 0011 | LOSS 0.0673
# TRAIN: EPOCH 0056 / 0100 | BATCH 0009 / 0011 | LOSS 0.0649
# TRAIN: EPOCH 0056 / 0100 | BATCH 0010 / 0011 | LOSS 0.0619
# TRAIN: EPOCH 0056 / 0100 | BATCH 0011 / 0011 | LOSS 0.0601
# TRAIN: EPOCH 0057 / 0100 | BATCH 0001 / 0011 | LOSS 0.0537
# TRAIN: EPOCH 0057 / 0100 | BATCH 0002 / 0011 | LOSS 0.0481
# TRAIN: EPOCH 0057 / 0100 | BATCH 0003 / 0011 | LOSS 0.0453
# TRAIN: EPOCH 0057 / 0100 | BATCH 0004 / 0011 | LOSS 0.0419
# TRAIN: EPOCH 0057 / 0100 | BATCH 0005 / 0011 | LOSS 0.0393
# TRAIN: EPOCH 0057 / 0100 | BATCH 0006 / 0011 | LOSS 0.0410
# TRAIN: EPOCH 0057 / 0100 | BATCH 0007 / 0011 | LOSS 0.0496
# TRAIN: EPOCH 0057 / 0100 | BATCH 0008 / 0011 | LOSS 0.0605
# TRAIN: EPOCH 0057 / 0100 | BATCH 0009 / 0011 | LOSS 0.0648
# TRAIN: EPOCH 0057 / 0100 | BATCH 0010 / 0011 | LOSS 0.0613
# TRAIN: EPOCH 0057 / 0100 | BATCH 0011 / 0011 | LOSS 0.0681
# TRAIN: EPOCH 0058 / 0100 | BATCH 0001 / 0011 | LOSS 0.0475
# TRAIN: EPOCH 0058 / 0100 | BATCH 0002 / 0011 | LOSS 0.0537
# TRAIN: EPOCH 0058 / 0100 | BATCH 0003 / 0011 | LOSS 0.0583
# TRAIN: EPOCH 0058 / 0100 | BATCH 0004 / 0011 | LOSS 0.0535
# TRAIN: EPOCH 0058 / 0100 | BATCH 0005 / 0011 | LOSS 0.0538
# TRAIN: EPOCH 0058 / 0100 | BATCH 0006 / 0011 | LOSS 0.0621
# TRAIN: EPOCH 0058 / 0100 | BATCH 0007 / 0011 | LOSS 0.0674
# TRAIN: EPOCH 0058 / 0100 | BATCH 0008 / 0011 | LOSS 0.0632
# TRAIN: EPOCH 0058 / 0100 | BATCH 0009 / 0011 | LOSS 0.0606
# TRAIN: EPOCH 0058 / 0100 | BATCH 0010 / 0011 | LOSS 0.0628
# TRAIN: EPOCH 0058 / 0100 | BATCH 0011 / 0011 | LOSS 0.0596
# TRAIN: EPOCH 0059 / 0100 | BATCH 0001 / 0011 | LOSS 0.0414
# TRAIN: EPOCH 0059 / 0100 | BATCH 0002 / 0011 | LOSS 0.0364
# TRAIN: EPOCH 0059 / 0100 | BATCH 0003 / 0011 | LOSS 0.0387
# TRAIN: EPOCH 0059 / 0100 | BATCH 0004 / 0011 | LOSS 0.0381
# TRAIN: EPOCH 0059 / 0100 | BATCH 0005 / 0011 | LOSS 0.0425
# TRAIN: EPOCH 0059 / 0100 | BATCH 0006 / 0011 | LOSS 0.0435
# TRAIN: EPOCH 0059 / 0100 | BATCH 0007 / 0011 | LOSS 0.0526
# TRAIN: EPOCH 0059 / 0100 | BATCH 0008 / 0011 | LOSS 0.0569
# TRAIN: EPOCH 0059 / 0100 | BATCH 0009 / 0011 | LOSS 0.0554
# TRAIN: EPOCH 0059 / 0100 | BATCH 0010 / 0011 | LOSS 0.0583
# TRAIN: EPOCH 0059 / 0100 | BATCH 0011 / 0011 | LOSS 0.0676
# TRAIN: EPOCH 0060 / 0100 | BATCH 0001 / 0011 | LOSS 0.0379
# TRAIN: EPOCH 0060 / 0100 | BATCH 0002 / 0011 | LOSS 0.0448
# TRAIN: EPOCH 0060 / 0100 | BATCH 0003 / 0011 | LOSS 0.0408
# TRAIN: EPOCH 0060 / 0100 | BATCH 0004 / 0011 | LOSS 0.0385
# TRAIN: EPOCH 0060 / 0100 | BATCH 0005 / 0011 | LOSS 0.0438
# TRAIN: EPOCH 0060 / 0100 | BATCH 0006 / 0011 | LOSS 0.0426
# TRAIN: EPOCH 0060 / 0100 | BATCH 0007 / 0011 | LOSS 0.0475
# TRAIN: EPOCH 0060 / 0100 | BATCH 0008 / 0011 | LOSS 0.0470
# TRAIN: EPOCH 0060 / 0100 | BATCH 0009 / 0011 | LOSS 0.0527
# TRAIN: EPOCH 0060 / 0100 | BATCH 0010 / 0011 | LOSS 0.0571
# TRAIN: EPOCH 0060 / 0100 | BATCH 0011 / 0011 | LOSS 0.0608
# TRAIN: EPOCH 0061 / 0100 | BATCH 0001 / 0011 | LOSS 0.0868
# TRAIN: EPOCH 0061 / 0100 | BATCH 0002 / 0011 | LOSS 0.0730
# TRAIN: EPOCH 0061 / 0100 | BATCH 0003 / 0011 | LOSS 0.0631
# TRAIN: EPOCH 0061 / 0100 | BATCH 0004 / 0011 | LOSS 0.0586
# TRAIN: EPOCH 0061 / 0100 | BATCH 0005 / 0011 | LOSS 0.0614
# TRAIN: EPOCH 0061 / 0100 | BATCH 0006 / 0011 | LOSS 0.0581
# TRAIN: EPOCH 0061 / 0100 | BATCH 0007 / 0011 | LOSS 0.0559
# TRAIN: EPOCH 0061 / 0100 | BATCH 0008 / 0011 | LOSS 0.0534
# TRAIN: EPOCH 0061 / 0100 | BATCH 0009 / 0011 | LOSS 0.0603
# TRAIN: EPOCH 0061 / 0100 | BATCH 0010 / 0011 | LOSS 0.0648
# TRAIN: EPOCH 0061 / 0100 | BATCH 0011 / 0011 | LOSS 0.0619
# TRAIN: EPOCH 0062 / 0100 | BATCH 0001 / 0011 | LOSS 0.0614
# TRAIN: EPOCH 0062 / 0100 | BATCH 0002 / 0011 | LOSS 0.0533
# TRAIN: EPOCH 0062 / 0100 | BATCH 0003 / 0011 | LOSS 0.0491
# TRAIN: EPOCH 0062 / 0100 | BATCH 0004 / 0011 | LOSS 0.0494
# TRAIN: EPOCH 0062 / 0100 | BATCH 0005 / 0011 | LOSS 0.0603
# TRAIN: EPOCH 0062 / 0100 | BATCH 0006 / 0011 | LOSS 0.0643
# TRAIN: EPOCH 0062 / 0100 | BATCH 0007 / 0011 | LOSS 0.0610
# TRAIN: EPOCH 0062 / 0100 | BATCH 0008 / 0011 | LOSS 0.0592
# TRAIN: EPOCH 0062 / 0100 | BATCH 0009 / 0011 | LOSS 0.0626
# TRAIN: EPOCH 0062 / 0100 | BATCH 0010 / 0011 | LOSS 0.0606
# TRAIN: EPOCH 0062 / 0100 | BATCH 0011 / 0011 | LOSS 0.0586
# TRAIN: EPOCH 0063 / 0100 | BATCH 0001 / 0011 | LOSS 0.0478
# TRAIN: EPOCH 0063 / 0100 | BATCH 0002 / 0011 | LOSS 0.0752
# TRAIN: EPOCH 0063 / 0100 | BATCH 0003 / 0011 | LOSS 0.0778
# TRAIN: EPOCH 0063 / 0100 | BATCH 0004 / 0011 | LOSS 0.0690
# TRAIN: EPOCH 0063 / 0100 | BATCH 0005 / 0011 | LOSS 0.0617
# TRAIN: EPOCH 0063 / 0100 | BATCH 0006 / 0011 | LOSS 0.0584
# TRAIN: EPOCH 0063 / 0100 | BATCH 0007 / 0011 | LOSS 0.0547
# TRAIN: EPOCH 0063 / 0100 | BATCH 0008 / 0011 | LOSS 0.0525
# TRAIN: EPOCH 0063 / 0100 | BATCH 0009 / 0011 | LOSS 0.0579
# TRAIN: EPOCH 0063 / 0100 | BATCH 0010 / 0011 | LOSS 0.0594
# TRAIN: EPOCH 0063 / 0100 | BATCH 0011 / 0011 | LOSS 0.0583
# TRAIN: EPOCH 0064 / 0100 | BATCH 0001 / 0011 | LOSS 0.0286
# TRAIN: EPOCH 0064 / 0100 | BATCH 0002 / 0011 | LOSS 0.0297
# TRAIN: EPOCH 0064 / 0100 | BATCH 0003 / 0011 | LOSS 0.0334
# TRAIN: EPOCH 0064 / 0100 | BATCH 0004 / 0011 | LOSS 0.0335
# TRAIN: EPOCH 0064 / 0100 | BATCH 0005 / 0011 | LOSS 0.0503
# TRAIN: EPOCH 0064 / 0100 | BATCH 0006 / 0011 | LOSS 0.0564
# TRAIN: EPOCH 0064 / 0100 | BATCH 0007 / 0011 | LOSS 0.0532
# TRAIN: EPOCH 0064 / 0100 | BATCH 0008 / 0011 | LOSS 0.0581
# TRAIN: EPOCH 0064 / 0100 | BATCH 0009 / 0011 | LOSS 0.0555
# TRAIN: EPOCH 0064 / 0100 | BATCH 0010 / 0011 | LOSS 0.0582
# TRAIN: EPOCH 0064 / 0100 | BATCH 0011 / 0011 | LOSS 0.0562
# TRAIN: EPOCH 0065 / 0100 | BATCH 0001 / 0011 | LOSS 0.0309
# TRAIN: EPOCH 0065 / 0100 | BATCH 0002 / 0011 | LOSS 0.0677
# TRAIN: EPOCH 0065 / 0100 | BATCH 0003 / 0011 | LOSS 0.0690
# TRAIN: EPOCH 0065 / 0100 | BATCH 0004 / 0011 | LOSS 0.0618
# TRAIN: EPOCH 0065 / 0100 | BATCH 0005 / 0011 | LOSS 0.0567
# TRAIN: EPOCH 0065 / 0100 | BATCH 0006 / 0011 | LOSS 0.0526
# TRAIN: EPOCH 0065 / 0100 | BATCH 0007 / 0011 | LOSS 0.0595
# TRAIN: EPOCH 0065 / 0100 | BATCH 0008 / 0011 | LOSS 0.0559
# TRAIN: EPOCH 0065 / 0100 | BATCH 0009 / 0011 | LOSS 0.0536
# TRAIN: EPOCH 0065 / 0100 | BATCH 0010 / 0011 | LOSS 0.0542
# TRAIN: EPOCH 0065 / 0100 | BATCH 0011 / 0011 | LOSS 0.0627
# TRAIN: EPOCH 0066 / 0100 | BATCH 0001 / 0011 | LOSS 0.0342
# TRAIN: EPOCH 0066 / 0100 | BATCH 0002 / 0011 | LOSS 0.0312
# TRAIN: EPOCH 0066 / 0100 | BATCH 0003 / 0011 | LOSS 0.0305
# TRAIN: EPOCH 0066 / 0100 | BATCH 0004 / 0011 | LOSS 0.0317
# TRAIN: EPOCH 0066 / 0100 | BATCH 0005 / 0011 | LOSS 0.0453
# TRAIN: EPOCH 0066 / 0100 | BATCH 0006 / 0011 | LOSS 0.0431
# TRAIN: EPOCH 0066 / 0100 | BATCH 0007 / 0011 | LOSS 0.0493
# TRAIN: EPOCH 0066 / 0100 | BATCH 0008 / 0011 | LOSS 0.0570
# TRAIN: EPOCH 0066 / 0100 | BATCH 0009 / 0011 | LOSS 0.0551
# TRAIN: EPOCH 0066 / 0100 | BATCH 0010 / 0011 | LOSS 0.0539
# TRAIN: EPOCH 0066 / 0100 | BATCH 0011 / 0011 | LOSS 0.0604
# TRAIN: EPOCH 0067 / 0100 | BATCH 0001 / 0011 | LOSS 0.0407
# TRAIN: EPOCH 0067 / 0100 | BATCH 0002 / 0011 | LOSS 0.0367
# TRAIN: EPOCH 0067 / 0100 | BATCH 0003 / 0011 | LOSS 0.0431
# TRAIN: EPOCH 0067 / 0100 | BATCH 0004 / 0011 | LOSS 0.0409
# TRAIN: EPOCH 0067 / 0100 | BATCH 0005 / 0011 | LOSS 0.0411
# TRAIN: EPOCH 0067 / 0100 | BATCH 0006 / 0011 | LOSS 0.0410
# TRAIN: EPOCH 0067 / 0100 | BATCH 0007 / 0011 | LOSS 0.0393
# TRAIN: EPOCH 0067 / 0100 | BATCH 0008 / 0011 | LOSS 0.0383
# TRAIN: EPOCH 0067 / 0100 | BATCH 0009 / 0011 | LOSS 0.0534
# TRAIN: EPOCH 0067 / 0100 | BATCH 0010 / 0011 | LOSS 0.0573
# TRAIN: EPOCH 0067 / 0100 | BATCH 0011 / 0011 | LOSS 0.0635
# TRAIN: EPOCH 0068 / 0100 | BATCH 0001 / 0011 | LOSS 0.0641
# TRAIN: EPOCH 0068 / 0100 | BATCH 0002 / 0011 | LOSS 0.0782
# TRAIN: EPOCH 0068 / 0100 | BATCH 0003 / 0011 | LOSS 0.0820
# TRAIN: EPOCH 0068 / 0100 | BATCH 0004 / 0011 | LOSS 0.0783
# TRAIN: EPOCH 0068 / 0100 | BATCH 0005 / 0011 | LOSS 0.0720
# TRAIN: EPOCH 0068 / 0100 | BATCH 0006 / 0011 | LOSS 0.0745
# TRAIN: EPOCH 0068 / 0100 | BATCH 0007 / 0011 | LOSS 0.0716
# TRAIN: EPOCH 0068 / 0100 | BATCH 0008 / 0011 | LOSS 0.0697
# TRAIN: EPOCH 0068 / 0100 | BATCH 0009 / 0011 | LOSS 0.0659
# TRAIN: EPOCH 0068 / 0100 | BATCH 0010 / 0011 | LOSS 0.0638
# TRAIN: EPOCH 0068 / 0100 | BATCH 0011 / 0011 | LOSS 0.0629
# TRAIN: EPOCH 0069 / 0100 | BATCH 0001 / 0011 | LOSS 0.0513
# TRAIN: EPOCH 0069 / 0100 | BATCH 0002 / 0011 | LOSS 0.0493
# TRAIN: EPOCH 0069 / 0100 | BATCH 0003 / 0011 | LOSS 0.0520
# TRAIN: EPOCH 0069 / 0100 | BATCH 0004 / 0011 | LOSS 0.0477
# TRAIN: EPOCH 0069 / 0100 | BATCH 0005 / 0011 | LOSS 0.0449
# TRAIN: EPOCH 0069 / 0100 | BATCH 0006 / 0011 | LOSS 0.0544
# TRAIN: EPOCH 0069 / 0100 | BATCH 0007 / 0011 | LOSS 0.0515
# TRAIN: EPOCH 0069 / 0100 | BATCH 0008 / 0011 | LOSS 0.0568
# TRAIN: EPOCH 0069 / 0100 | BATCH 0009 / 0011 | LOSS 0.0592
# TRAIN: EPOCH 0069 / 0100 | BATCH 0010 / 0011 | LOSS 0.0579
# TRAIN: EPOCH 0069 / 0100 | BATCH 0011 / 0011 | LOSS 0.0643
# TRAIN: EPOCH 0070 / 0100 | BATCH 0001 / 0011 | LOSS 0.0427
# TRAIN: EPOCH 0070 / 0100 | BATCH 0002 / 0011 | LOSS 0.0729
# TRAIN: EPOCH 0070 / 0100 | BATCH 0003 / 0011 | LOSS 0.0583
# TRAIN: EPOCH 0070 / 0100 | BATCH 0004 / 0011 | LOSS 0.0668
# TRAIN: EPOCH 0070 / 0100 | BATCH 0005 / 0011 | LOSS 0.0660
# TRAIN: EPOCH 0070 / 0100 | BATCH 0006 / 0011 | LOSS 0.0718
# TRAIN: EPOCH 0070 / 0100 | BATCH 0007 / 0011 | LOSS 0.0674
# TRAIN: EPOCH 0070 / 0100 | BATCH 0008 / 0011 | LOSS 0.0637
# TRAIN: EPOCH 0070 / 0100 | BATCH 0009 / 0011 | LOSS 0.0637
# TRAIN: EPOCH 0070 / 0100 | BATCH 0010 / 0011 | LOSS 0.0612
# TRAIN: EPOCH 0070 / 0100 | BATCH 0011 / 0011 | LOSS 0.0592
# TRAIN: EPOCH 0071 / 0100 | BATCH 0001 / 0011 | LOSS 0.0305
# TRAIN: EPOCH 0071 / 0100 | BATCH 0002 / 0011 | LOSS 0.0571
# TRAIN: EPOCH 0071 / 0100 | BATCH 0003 / 0011 | LOSS 0.0525
# TRAIN: EPOCH 0071 / 0100 | BATCH 0004 / 0011 | LOSS 0.0483
# TRAIN: EPOCH 0071 / 0100 | BATCH 0005 / 0011 | LOSS 0.0545
# TRAIN: EPOCH 0071 / 0100 | BATCH 0006 / 0011 | LOSS 0.0613
# TRAIN: EPOCH 0071 / 0100 | BATCH 0007 / 0011 | LOSS 0.0569
# TRAIN: EPOCH 0071 / 0100 | BATCH 0008 / 0011 | LOSS 0.0614
# TRAIN: EPOCH 0071 / 0100 | BATCH 0009 / 0011 | LOSS 0.0584
# TRAIN: EPOCH 0071 / 0100 | BATCH 0010 / 0011 | LOSS 0.0565
# TRAIN: EPOCH 0071 / 0100 | BATCH 0011 / 0011 | LOSS 0.0545
# TRAIN: EPOCH 0072 / 0100 | BATCH 0001 / 0011 | LOSS 0.0423
# TRAIN: EPOCH 0072 / 0100 | BATCH 0002 / 0011 | LOSS 0.0697
# TRAIN: EPOCH 0072 / 0100 | BATCH 0003 / 0011 | LOSS 0.0735
# TRAIN: EPOCH 0072 / 0100 | BATCH 0004 / 0011 | LOSS 0.0682
# TRAIN: EPOCH 0072 / 0100 | BATCH 0005 / 0011 | LOSS 0.0655
# TRAIN: EPOCH 0072 / 0100 | BATCH 0006 / 0011 | LOSS 0.0595
# TRAIN: EPOCH 0072 / 0100 | BATCH 0007 / 0011 | LOSS 0.0648
# TRAIN: EPOCH 0072 / 0100 | BATCH 0008 / 0011 | LOSS 0.0615
# TRAIN: EPOCH 0072 / 0100 | BATCH 0009 / 0011 | LOSS 0.0587
# ...
# TRAIN: EPOCH 0076 / 0100 | BATCH 0005 / 0011 | LOSS 0.0580
# TRAIN: EPOCH 0076 / 0100 | BATCH 0006 / 0011 | LOSS 0.0533
# TRAIN: EPOCH 0076 / 0100 | BATCH 0007 / 0011 | LOSS 0.0558
# TRAIN: EPOCH 0076 / 0100 | BATCH 0008 / 0011 | LOSS 0.0567
# TRAIN: EPOCH 0076 / 0100 | BATCH 0009 / 0011 | LOSS 0.0551
# TRAIN: EPOCH 0076 / 0100 | BATCH 0010 / 0011 | LOSS 0.0522
# TRAIN: EPOCH 0076 / 0100 | BATCH 0011 / 0011 | LOSS 0.0623
# TRAIN: EPOCH 0077 / 0100 | BATCH 0001 / 0011 | LOSS 0.0816
# TRAIN: EPOCH 0077 / 0100 | BATCH 0002 / 0011 | LOSS 0.0578
# TRAIN: EPOCH 0077 / 0100 | BATCH 0003 / 0011 | LOSS 0.0501
# TRAIN: EPOCH 0077 / 0100 | BATCH 0004 / 0011 | LOSS 0.0615
# TRAIN: EPOCH 0077 / 0100 | BATCH 0005 / 0011 | LOSS 0.0572
# TRAIN: EPOCH 0077 / 0100 | BATCH 0006 / 0011 | LOSS 0.0535
# TRAIN: EPOCH 0077 / 0100 | BATCH 0007 / 0011 | LOSS 0.0509
# TRAIN: EPOCH 0077 / 0100 | BATCH 0008 / 0011 | LOSS 0.0638
# TRAIN: EPOCH 0077 / 0100 | BATCH 0009 / 0011 | LOSS 0.0623
# TRAIN: EPOCH 0077 / 0100 | BATCH 0010 / 0011 | LOSS 0.0594
# TRAIN: EPOCH 0077 / 0100 | BATCH 0011 / 0011 | LOSS 0.0565
# TRAIN: EPOCH 0078 / 0100 | BATCH 0001 / 0011 | LOSS 0.0669
# TRAIN: EPOCH 0078 / 0100 | BATCH 0002 / 0011 | LOSS 0.0525
# TRAIN: EPOCH 0078 / 0100 | BATCH 0003 / 0011 | LOSS 0.0497
# TRAIN: EPOCH 0078 / 0100 | BATCH 0004 / 0011 | LOSS 0.0594
# TRAIN: EPOCH 0078 / 0100 | BATCH 0005 / 0011 | LOSS 0.0551
# TRAIN: EPOCH 0078 / 0100 | BATCH 0006 / 0011 | LOSS 0.0520
# TRAIN: EPOCH 0078 / 0100 | BATCH 0007 / 0011 | LOSS 0.0557
# TRAIN: EPOCH 0078 / 0100 | BATCH 0008 / 0011 | LOSS 0.0612
# TRAIN: EPOCH 0078 / 0100 | BATCH 0009 / 0011 | LOSS 0.0574
# TRAIN: EPOCH 0078 / 0100 | BATCH 0010 / 0011 | LOSS 0.0568
# TRAIN: EPOCH 0078 / 0100 | BATCH 0011 / 0011 | LOSS 0.0553
# TRAIN: EPOCH 0079 / 0100 | BATCH 0001 / 0011 | LOSS 0.0438
# TRAIN: EPOCH 0079 / 0100 | BATCH 0002 / 0011 | LOSS 0.0379
# TRAIN: EPOCH 0079 / 0100 | BATCH 0003 / 0011 | LOSS 0.0363
# TRAIN: EPOCH 0079 / 0100 | BATCH 0004 / 0011 | LOSS 0.0525
# TRAIN: EPOCH 0079 / 0100 | BATCH 0005 / 0011 | LOSS 0.0494
# TRAIN: EPOCH 0079 / 0100 | BATCH 0006 / 0011 | LOSS 0.0467
# TRAIN: EPOCH 0079 / 0100 | BATCH 0007 / 0011 | LOSS 0.0556
# TRAIN: EPOCH 0079 / 0100 | BATCH 0008 / 0011 | LOSS 0.0616
# TRAIN: EPOCH 0079 / 0100 | BATCH 0009 / 0011 | LOSS 0.0586
# TRAIN: EPOCH 0079 / 0100 | BATCH 0010 / 0011 | LOSS 0.0594
# TRAIN: EPOCH 0079 / 0100 | BATCH 0011 / 0011 | LOSS 0.0567
# TRAIN: EPOCH 0080 / 0100 | BATCH 0001 / 0011 | LOSS 0.0337
# TRAIN: EPOCH 0080 / 0100 | BATCH 0002 / 0011 | LOSS 0.0358
# TRAIN: EPOCH 0080 / 0100 | BATCH 0003 / 0011 | LOSS 0.0513
# TRAIN: EPOCH 0080 / 0100 | BATCH 0004 / 0011 | LOSS 0.0475
# TRAIN: EPOCH 0080 / 0100 | BATCH 0005 / 0011 | LOSS 0.0465
# TRAIN: EPOCH 0080 / 0100 | BATCH 0006 / 0011 | LOSS 0.0544
# TRAIN: EPOCH 0080 / 0100 | BATCH 0007 / 0011 | LOSS 0.0554
# TRAIN: EPOCH 0080 / 0100 | BATCH 0008 / 0011 | LOSS 0.0515
# TRAIN: EPOCH 0080 / 0100 | BATCH 0009 / 0011 | LOSS 0.0515
# TRAIN: EPOCH 0080 / 0100 | BATCH 0010 / 0011 | LOSS 0.0511
# TRAIN: EPOCH 0080 / 0100 | BATCH 0011 / 0011 | LOSS 0.0640
# TRAIN: EPOCH 0081 / 0100 | BATCH 0001 / 0011 | LOSS 0.0644
# TRAIN: EPOCH 0081 / 0100 | BATCH 0002 / 0011 | LOSS 0.0482
# TRAIN: EPOCH 0081 / 0100 | BATCH 0003 / 0011 | LOSS 0.0633
# TRAIN: EPOCH 0081 / 0100 | BATCH 0004 / 0011 | LOSS 0.0550
# TRAIN: EPOCH 0081 / 0100 | BATCH 0005 / 0011 | LOSS 0.0528
# TRAIN: EPOCH 0081 / 0100 | BATCH 0006 / 0011 | LOSS 0.0580
# TRAIN: EPOCH 0081 / 0100 | BATCH 0007 / 0011 | LOSS 0.0547
# TRAIN: EPOCH 0081 / 0100 | BATCH 0008 / 0011 | LOSS 0.0601
# TRAIN: EPOCH 0081 / 0100 | BATCH 0009 / 0011 | LOSS 0.0575
# TRAIN: EPOCH 0081 / 0100 | BATCH 0010 / 0011 | LOSS 0.0595
# TRAIN: EPOCH 0081 / 0100 | BATCH 0011 / 0011 | LOSS 0.0576
# TRAIN: EPOCH 0082 / 0100 | BATCH 0001 / 0011 | LOSS 0.0791
# TRAIN: EPOCH 0082 / 0100 | BATCH 0002 / 0011 | LOSS 0.0927
# TRAIN: EPOCH 0082 / 0100 | BATCH 0003 / 0011 | LOSS 0.0916
# TRAIN: EPOCH 0082 / 0100 | BATCH 0004 / 0011 | LOSS 0.0787
# TRAIN: EPOCH 0082 / 0100 | BATCH 0005 / 0011 | LOSS 0.0761
# TRAIN: EPOCH 0082 / 0100 | BATCH 0006 / 0011 | LOSS 0.0686
# TRAIN: EPOCH 0082 / 0100 | BATCH 0007 / 0011 | LOSS 0.0672
# TRAIN: EPOCH 0082 / 0100 | BATCH 0008 / 0011 | LOSS 0.0669
# TRAIN: EPOCH 0082 / 0100 | BATCH 0009 / 0011 | LOSS 0.0639
# TRAIN: EPOCH 0082 / 0100 | BATCH 0010 / 0011 | LOSS 0.0621
# TRAIN: EPOCH 0082 / 0100 | BATCH 0011 / 0011 | LOSS 0.0596
# TRAIN: EPOCH 0083 / 0100 | BATCH 0001 / 0011 | LOSS 0.0382
# TRAIN: EPOCH 0083 / 0100 | BATCH 0002 / 0011 | LOSS 0.0399
# TRAIN: EPOCH 0083 / 0100 | BATCH 0003 / 0011 | LOSS 0.0375
# TRAIN: EPOCH 0083 / 0100 | BATCH 0004 / 0011 | LOSS 0.0692
# TRAIN: EPOCH 0083 / 0100 | BATCH 0005 / 0011 | LOSS 0.0654
# TRAIN: EPOCH 0083 / 0100 | BATCH 0006 / 0011 | LOSS 0.0610
# TRAIN: EPOCH 0083 / 0100 | BATCH 0007 / 0011 | LOSS 0.0618
# TRAIN: EPOCH 0083 / 0100 | BATCH 0008 / 0011 | LOSS 0.0578
# TRAIN: EPOCH 0083 / 0100 | BATCH 0009 / 0011 | LOSS 0.0624
# TRAIN: EPOCH 0083 / 0100 | BATCH 0010 / 0011 | LOSS 0.0601
# TRAIN: EPOCH 0083 / 0100 | BATCH 0011 / 0011 | LOSS 0.0576
# TRAIN: EPOCH 0084 / 0100 | BATCH 0001 / 0011 | LOSS 0.0804
# TRAIN: EPOCH 0084 / 0100 | BATCH 0002 / 0011 | LOSS 0.0589
# TRAIN: EPOCH 0084 / 0100 | BATCH 0003 / 0011 | LOSS 0.0489
# TRAIN: EPOCH 0084 / 0100 | BATCH 0004 / 0011 | LOSS 0.0485
# TRAIN: EPOCH 0084 / 0100 | BATCH 0005 / 0011 | LOSS 0.0530
# TRAIN: EPOCH 0084 / 0100 | BATCH 0006 / 0011 | LOSS 0.0493
# TRAIN: EPOCH 0084 / 0100 | BATCH 0007 / 0011 | LOSS 0.0465
# TRAIN: EPOCH 0084 / 0100 | BATCH 0008 / 0011 | LOSS 0.0553
# TRAIN: EPOCH 0084 / 0100 | BATCH 0009 / 0011 | LOSS 0.0605
# TRAIN: EPOCH 0084 / 0100 | BATCH 0010 / 0011 | LOSS 0.0574
# TRAIN: EPOCH 0084 / 0100 | BATCH 0011 / 0011 | LOSS 0.0556
# TRAIN: EPOCH 0085 / 0100 | BATCH 0001 / 0011 | LOSS 0.0319
# TRAIN: EPOCH 0085 / 0100 | BATCH 0002 / 0011 | LOSS 0.0310
# TRAIN: EPOCH 0085 / 0100 | BATCH 0003 / 0011 | LOSS 0.0533
# TRAIN: EPOCH 0085 / 0100 | BATCH 0004 / 0011 | LOSS 0.0637
# TRAIN: EPOCH 0085 / 0100 | BATCH 0005 / 0011 | LOSS 0.0568
# TRAIN: EPOCH 0085 / 0100 | BATCH 0006 / 0011 | LOSS 0.0598
# TRAIN: EPOCH 0085 / 0100 | BATCH 0007 / 0011 | LOSS 0.0569
# TRAIN: EPOCH 0085 / 0100 | BATCH 0008 / 0011 | LOSS 0.0544
# TRAIN: EPOCH 0085 / 0100 | BATCH 0009 / 0011 | LOSS 0.0525
# TRAIN: EPOCH 0085 / 0100 | BATCH 0010 / 0011 | LOSS 0.0508
# TRAIN: EPOCH 0085 / 0100 | BATCH 0011 / 0011 | LOSS 0.0637
# TRAIN: EPOCH 0086 / 0100 | BATCH 0001 / 0011 | LOSS 0.0293
# TRAIN: EPOCH 0086 / 0100 | BATCH 0002 / 0011 | LOSS 0.0289
# TRAIN: EPOCH 0086 / 0100 | BATCH 0003 / 0011 | LOSS 0.0281
# TRAIN: EPOCH 0086 / 0100 | BATCH 0004 / 0011 | LOSS 0.0320
# TRAIN: EPOCH 0086 / 0100 | BATCH 0005 / 0011 | LOSS 0.0348
# TRAIN: EPOCH 0086 / 0100 | BATCH 0006 / 0011 | LOSS 0.0433
# TRAIN: EPOCH 0086 / 0100 | BATCH 0007 / 0011 | LOSS 0.0418
# TRAIN: EPOCH 0086 / 0100 | BATCH 0008 / 0011 | LOSS 0.0412
# TRAIN: EPOCH 0086 / 0100 | BATCH 0009 / 0011 | LOSS 0.0408
# TRAIN: EPOCH 0086 / 0100 | BATCH 0010 / 0011 | LOSS 0.0548
# TRAIN: EPOCH 0086 / 0100 | BATCH 0011 / 0011 | LOSS 0.0623
# TRAIN: EPOCH 0087 / 0100 | BATCH 0001 / 0011 | LOSS 0.0349
# TRAIN: EPOCH 0087 / 0100 | BATCH 0002 / 0011 | LOSS 0.0350
# TRAIN: EPOCH 0087 / 0100 | BATCH 0003 / 0011 | LOSS 0.0541
# TRAIN: EPOCH 0087 / 0100 | BATCH 0004 / 0011 | LOSS 0.0498
# TRAIN: EPOCH 0087 / 0100 | BATCH 0005 / 0011 | LOSS 0.0475
# TRAIN: EPOCH 0087 / 0100 | BATCH 0006 / 0011 | LOSS 0.0569
# TRAIN: EPOCH 0087 / 0100 | BATCH 0007 / 0011 | LOSS 0.0555
# TRAIN: EPOCH 0087 / 0100 | BATCH 0008 / 0011 | LOSS 0.0524
# TRAIN: EPOCH 0087 / 0100 | BATCH 0009 / 0011 | LOSS 0.0555
# TRAIN: EPOCH 0087 / 0100 | BATCH 0010 / 0011 | LOSS 0.0562
# TRAIN: EPOCH 0087 / 0100 | BATCH 0011 / 0011 | LOSS 0.0547
# TRAIN: EPOCH 0088 / 0100 | BATCH 0001 / 0011 | LOSS 0.0456
# TRAIN: EPOCH 0088 / 0100 | BATCH 0002 / 0011 | LOSS 0.0397
# TRAIN: EPOCH 0088 / 0100 | BATCH 0003 / 0011 | LOSS 0.0745
# TRAIN: EPOCH 0088 / 0100 | BATCH 0004 / 0011 | LOSS 0.0672
# TRAIN: EPOCH 0088 / 0100 | BATCH 0005 / 0011 | LOSS 0.0607
# TRAIN: EPOCH 0088 / 0100 | BATCH 0006 / 0011 | LOSS 0.0561
# TRAIN: EPOCH 0088 / 0100 | BATCH 0007 / 0011 | LOSS 0.0538
# TRAIN: EPOCH 0088 / 0100 | BATCH 0008 / 0011 | LOSS 0.0509
# TRAIN: EPOCH 0088 / 0100 | BATCH 0009 / 0011 | LOSS 0.0542
# TRAIN: EPOCH 0088 / 0100 | BATCH 0010 / 0011 | LOSS 0.0533
# TRAIN: EPOCH 0088 / 0100 | BATCH 0011 / 0011 | LOSS 0.0623
# TRAIN: EPOCH 0089 / 0100 | BATCH 0001 / 0011 | LOSS 0.1071
# TRAIN: EPOCH 0089 / 0100 | BATCH 0002 / 0011 | LOSS 0.0987
# TRAIN: EPOCH 0089 / 0100 | BATCH 0003 / 0011 | LOSS 0.0816
# TRAIN: EPOCH 0089 / 0100 | BATCH 0004 / 0011 | LOSS 0.0708
# TRAIN: EPOCH 0089 / 0100 | BATCH 0005 / 0011 | LOSS 0.0642
# TRAIN: EPOCH 0089 / 0100 | BATCH 0006 / 0011 | LOSS 0.0592
# TRAIN: EPOCH 0089 / 0100 | BATCH 0007 / 0011 | LOSS 0.0560
# TRAIN: EPOCH 0089 / 0100 | BATCH 0008 / 0011 | LOSS 0.0580
# TRAIN: EPOCH 0089 / 0100 | BATCH 0009 / 0011 | LOSS 0.0588
# TRAIN: EPOCH 0089 / 0100 | BATCH 0010 / 0011 | LOSS 0.0576
# TRAIN: EPOCH 0089 / 0100 | BATCH 0011 / 0011 | LOSS 0.0555
# TRAIN: EPOCH 0090 / 0100 | BATCH 0001 / 0011 | LOSS 0.0383
# TRAIN: EPOCH 0090 / 0100 | BATCH 0002 / 0011 | LOSS 0.0413
# TRAIN: EPOCH 0090 / 0100 | BATCH 0003 / 0011 | LOSS 0.0399
# TRAIN: EPOCH 0090 / 0100 | BATCH 0004 / 0011 | LOSS 0.0381
# TRAIN: EPOCH 0090 / 0100 | BATCH 0005 / 0011 | LOSS 0.0380
# TRAIN: EPOCH 0090 / 0100 | BATCH 0006 / 0011 | LOSS 0.0556
# TRAIN: EPOCH 0090 / 0100 | BATCH 0007 / 0011 | LOSS 0.0587
# TRAIN: EPOCH 0090 / 0100 | BATCH 0008 / 0011 | LOSS 0.0558
# TRAIN: EPOCH 0090 / 0100 | BATCH 0009 / 0011 | LOSS 0.0608
# TRAIN: EPOCH 0090 / 0100 | BATCH 0010 / 0011 | LOSS 0.0592
# TRAIN: EPOCH 0090 / 0100 | BATCH 0011 / 0011 | LOSS 0.0572
# TRAIN: EPOCH 0091 / 0100 | BATCH 0001 / 0011 | LOSS 0.1536
# TRAIN: EPOCH 0091 / 0100 | BATCH 0002 / 0011 | LOSS 0.0971
# TRAIN: EPOCH 0091 / 0100 | BATCH 0003 / 0011 | LOSS 0.0742
# TRAIN: EPOCH 0091 / 0100 | BATCH 0004 / 0011 | LOSS 0.0793
# TRAIN: EPOCH 0091 / 0100 | BATCH 0005 / 0011 | LOSS 0.0730
# TRAIN: EPOCH 0091 / 0100 | BATCH 0006 / 0011 | LOSS 0.0659
# TRAIN: EPOCH 0091 / 0100 | BATCH 0007 / 0011 | LOSS 0.0618
# TRAIN: EPOCH 0091 / 0100 | BATCH 0008 / 0011 | LOSS 0.0584
# TRAIN: EPOCH 0091 / 0100 | BATCH 0009 / 0011 | LOSS 0.0557
# TRAIN: EPOCH 0091 / 0100 | BATCH 0010 / 0011 | LOSS 0.0581
# TRAIN: EPOCH 0091 / 0100 | BATCH 0011 / 0011 | LOSS 0.0564
# TRAIN: EPOCH 0092 / 0100 | BATCH 0001 / 0011 | LOSS 0.0358
# TRAIN: EPOCH 0092 / 0100 | BATCH 0002 / 0011 | LOSS 0.0370
# TRAIN: EPOCH 0092 / 0100 | BATCH 0003 / 0011 | LOSS 0.0819
# TRAIN: EPOCH 0092 / 0100 | BATCH 0004 / 0011 | LOSS 0.0726
# TRAIN: EPOCH 0092 / 0100 | BATCH 0005 / 0011 | LOSS 0.0640
# TRAIN: EPOCH 0092 / 0100 | BATCH 0006 / 0011 | LOSS 0.0593
# TRAIN: EPOCH 0092 / 0100 | BATCH 0007 / 0011 | LOSS 0.0625
# TRAIN: EPOCH 0092 / 0100 | BATCH 0008 / 0011 | LOSS 0.0587
# TRAIN: EPOCH 0092 / 0100 | BATCH 0009 / 0011 | LOSS 0.0555
# TRAIN: EPOCH 0092 / 0100 | BATCH 0010 / 0011 | LOSS 0.0563
# TRAIN: EPOCH 0092 / 0100 | BATCH 0011 / 0011 | LOSS 0.0541
# TRAIN: EPOCH 0093 / 0100 | BATCH 0001 / 0011 | LOSS 0.0291
# TRAIN: EPOCH 0093 / 0100 | BATCH 0002 / 0011 | LOSS 0.0312
# TRAIN: EPOCH 0093 / 0100 | BATCH 0003 / 0011 | LOSS 0.0523
# TRAIN: EPOCH 0093 / 0100 | BATCH 0004 / 0011 | LOSS 0.0473
# TRAIN: EPOCH 0093 / 0100 | BATCH 0005 / 0011 | LOSS 0.0717
# TRAIN: EPOCH 0093 / 0100 | BATCH 0006 / 0011 | LOSS 0.0654
# TRAIN: EPOCH 0093 / 0100 | BATCH 0007 / 0011 | LOSS 0.0616
# TRAIN: EPOCH 0093 / 0100 | BATCH 0008 / 0011 | LOSS 0.0580
# TRAIN: EPOCH 0093 / 0100 | BATCH 0009 / 0011 | LOSS 0.0582
# TRAIN: EPOCH 0093 / 0100 | BATCH 0010 / 0011 | LOSS 0.0553
# TRAIN: EPOCH 0093 / 0100 | BATCH 0011 / 0011 | LOSS 0.0560
# TRAIN: EPOCH 0094 / 0100 | BATCH 0001 / 0011 | LOSS 0.0334
# TRAIN: EPOCH 0094 / 0100 | BATCH 0002 / 0011 | LOSS 0.0341
# TRAIN: EPOCH 0094 / 0100 | BATCH 0003 / 0011 | LOSS 0.0828
# TRAIN: EPOCH 0094 / 0100 | BATCH 0004 / 0011 | LOSS 0.0685
# TRAIN: EPOCH 0094 / 0100 | BATCH 0005 / 0011 | LOSS 0.0612
# TRAIN: EPOCH 0094 / 0100 | BATCH 0006 / 0011 | LOSS 0.0622
# TRAIN: EPOCH 0094 / 0100 | BATCH 0007 / 0011 | LOSS 0.0651
# TRAIN: EPOCH 0094 / 0100 | BATCH 0008 / 0011 | LOSS 0.0606
# TRAIN: EPOCH 0094 / 0100 | BATCH 0009 / 0011 | LOSS 0.0602
# TRAIN: EPOCH 0094 / 0100 | BATCH 0010 / 0011 | LOSS 0.0577
# TRAIN: EPOCH 0094 / 0100 | BATCH 0011 / 0011 | LOSS 0.0559
# TRAIN: EPOCH 0095 / 0100 | BATCH 0001 / 0011 | LOSS 0.0342
# TRAIN: EPOCH 0095 / 0100 | BATCH 0002 / 0011 | LOSS 0.0383
# TRAIN: EPOCH 0095 / 0100 | BATCH 0003 / 0011 | LOSS 0.0345
# TRAIN: EPOCH 0095 / 0100 | BATCH 0004 / 0011 | LOSS 0.0338
# TRAIN: EPOCH 0095 / 0100 | BATCH 0005 / 0011 | LOSS 0.0493
# TRAIN: EPOCH 0095 / 0100 | BATCH 0006 / 0011 | LOSS 0.0470
# TRAIN: EPOCH 0095 / 0100 | BATCH 0007 / 0011 | LOSS 0.0511
# TRAIN: EPOCH 0095 / 0100 | BATCH 0008 / 0011 | LOSS 0.0660
# TRAIN: EPOCH 0095 / 0100 | BATCH 0009 / 0011 | LOSS 0.0619
# TRAIN: EPOCH 0095 / 0100 | BATCH 0010 / 0011 | LOSS 0.0586
# TRAIN: EPOCH 0095 / 0100 | BATCH 0011 / 0011 | LOSS 0.0552
# TRAIN: EPOCH 0096 / 0100 | BATCH 0001 / 0011 | LOSS 0.0351
# TRAIN: EPOCH 0096 / 0100 | BATCH 0002 / 0011 | LOSS 0.0336
# TRAIN: EPOCH 0096 / 0100 | BATCH 0003 / 0011 | LOSS 0.0560
# TRAIN: EPOCH 0096 / 0100 | BATCH 0004 / 0011 | LOSS 0.0585
# TRAIN: EPOCH 0096 / 0100 | BATCH 0005 / 0011 | LOSS 0.0514
# TRAIN: EPOCH 0096 / 0100 | BATCH 0006 / 0011 | LOSS 0.0609
# TRAIN: EPOCH 0096 / 0100 | BATCH 0007 / 0011 | LOSS 0.0593
# TRAIN: EPOCH 0096 / 0100 | BATCH 0008 / 0011 | LOSS 0.0627
# TRAIN: EPOCH 0096 / 0100 | BATCH 0009 / 0011 | LOSS 0.0600
# TRAIN: EPOCH 0096 / 0100 | BATCH 0010 / 0011 | LOSS 0.0573
# TRAIN: EPOCH 0096 / 0100 | BATCH 0011 / 0011 | LOSS 0.0547
# TRAIN: EPOCH 0097 / 0100 | BATCH 0001 / 0011 | LOSS 0.0311
# TRAIN: EPOCH 0097 / 0100 | BATCH 0002 / 0011 | LOSS 0.0317
# TRAIN: EPOCH 0097 / 0100 | BATCH 0003 / 0011 | LOSS 0.0339
# TRAIN: EPOCH 0097 / 0100 | BATCH 0004 / 0011 | LOSS 0.0326
# TRAIN: EPOCH 0097 / 0100 | BATCH 0005 / 0011 | LOSS 0.0392
# TRAIN: EPOCH 0097 / 0100 | BATCH 0006 / 0011 | LOSS 0.0382
# TRAIN: EPOCH 0097 / 0100 | BATCH 0007 / 0011 | LOSS 0.0482
# TRAIN: EPOCH 0097 / 0100 | BATCH 0008 / 0011 | LOSS 0.0537
# TRAIN: EPOCH 0097 / 0100 | BATCH 0009 / 0011 | LOSS 0.0512
# TRAIN: EPOCH 0097 / 0100 | BATCH 0010 / 0011 | LOSS 0.0553
# TRAIN: EPOCH 0097 / 0100 | BATCH 0011 / 0011 | LOSS 0.0530
# TRAIN: EPOCH 0098 / 0100 | BATCH 0001 / 0011 | LOSS 0.0900
# TRAIN: EPOCH 0098 / 0100 | BATCH 0002 / 0011 | LOSS 0.0570
# TRAIN: EPOCH 0098 / 0100 | BATCH 0003 / 0011 | LOSS 0.0720
# TRAIN: EPOCH 0098 / 0100 | BATCH 0004 / 0011 | LOSS 0.0628
# TRAIN: EPOCH 0098 / 0100 | BATCH 0005 / 0011 | LOSS 0.0636
# TRAIN: EPOCH 0098 / 0100 | BATCH 0006 / 0011 | LOSS 0.0684
# TRAIN: EPOCH 0098 / 0100 | BATCH 0007 / 0011 | LOSS 0.0643
# TRAIN: EPOCH 0098 / 0100 | BATCH 0008 / 0011 | LOSS 0.0643
# TRAIN: EPOCH 0098 / 0100 | BATCH 0009 / 0011 | LOSS 0.0611
# TRAIN: EPOCH 0098 / 0100 | BATCH 0010 / 0011 | LOSS 0.0577
# TRAIN: EPOCH 0098 / 0100 | BATCH 0011 / 0011 | LOSS 0.0556
# TRAIN: EPOCH 0099 / 0100 | BATCH 0001 / 0011 | LOSS 0.0398
# TRAIN: EPOCH 0099 / 0100 | BATCH 0002 / 0011 | LOSS 0.0440
# TRAIN: EPOCH 0099 / 0100 | BATCH 0003 / 0011 | LOSS 0.0394
# TRAIN: EPOCH 0099 / 0100 | BATCH 0004 / 0011 | LOSS 0.0534
# TRAIN: EPOCH 0099 / 0100 | BATCH 0005 / 0011 | LOSS 0.0486
# TRAIN: EPOCH 0099 / 0100 | BATCH 0006 / 0011 | LOSS 0.0456
# TRAIN: EPOCH 0099 / 0100 | BATCH 0007 / 0011 | LOSS 0.0436
# TRAIN: EPOCH 0099 / 0100 | BATCH 0008 / 0011 | LOSS 0.0426
# TRAIN: EPOCH 0099 / 0100 | BATCH 0009 / 0011 | LOSS 0.0492
# TRAIN: EPOCH 0099 / 0100 | BATCH 0010 / 0011 | LOSS 0.0510
# TRAIN: EPOCH 0099 / 0100 | BATCH 0011 / 0011 | LOSS 0.0605
# TRAIN: EPOCH 0100 / 0100 | BATCH 0001 / 0011 | LOSS 0.0371
# TRAIN: EPOCH 0100 / 0100 | BATCH 0002 / 0011 | LOSS 0.0702
# TRAIN: EPOCH 0100 / 0100 | BATCH 0003 / 0011 | LOSS 0.0588
# TRAIN: EPOCH 0100 / 0100 | BATCH 0004 / 0011 | LOSS 0.0636
# TRAIN: EPOCH 0100 / 0100 | BATCH 0005 / 0011 | LOSS 0.0585
# TRAIN: EPOCH 0100 / 0100 | BATCH 0006 / 0011 | LOSS 0.0644
# TRAIN: EPOCH 0100 / 0100 | BATCH 0007 / 0011 | LOSS 0.0612
# TRAIN: EPOCH 0100 / 0100 | BATCH 0008 / 0011 | LOSS 0.0595
# TRAIN: EPOCH 0100 / 0100 | BATCH 0009 / 0011 | LOSS 0.0565
# TRAIN: EPOCH 0100 / 0100 | BATCH 0010 / 0011 | LOSS 0.0540
# TRAIN: EPOCH 0100 / 0100 | BATCH 0011 / 0011 | LOSS 0.0607

# %%
shutil.copy('/content/drive/MyDrive/2차 프로젝트 원본 데이터/데이터 원본/image/Female/153_F.jpg','/content/bone/datasets/imgs/test/153_F.png')
shutil.copy('/content/drive/MyDrive/2차 프로젝트 원본 데이터/데이터 원본/image/Female/322_F.jpg','/content/bone/datasets/imgs/test/322_F.png')
# Out:
# '/content/bone/datasets/imgs/test/322_F.png'

# %%
# # a = cv2.imread(bones[0])
# # plt.imshow(a)
# # print(a.shape)
# image = Image.open('/content/bone/datasets/masks/test/153_F.png')
# image = np.array(image)
# print(image)
# plt.imshow(image)
# # image.max()
# image.shape

img = cv2.imread('/content/bone/datasets/masks/test/153_F.png',cv2.IMREAD_GRAYSCALE)
plt.imshow(img)
img.shape
# Out:
# (1464, 1344)

# %%
a = cv2.imread('/content/bone/datasets/masks/train/14.png',cv2.IMREAD_GRAYSCALE)
plt.imshow(a)
a.shape
# Out:
# (1420, 1008)

# %%
PATH = '/content/bone/datasets/masks/test'
bones = glob(PATH+'/*.png')

# WIDTH = 800
# HEIGHT = 800

bones_box = np.zeros((len(bones),WIDTH,HEIGHT))

for num, bone in enumerate(bones):
    image_pil = cv2.imread(bone,cv2.IMREAD_GRAYSCALE)

#   image_pil = Image.open(bone)
#   image = np.array(image_pil)

    resized_image = cv2.resize(image_pil,(WIDTH,HEIGHT))

    # grey_image = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)
#   grey_image = resized_image.reshape(WIDTH,HEIGHT)

    bones_box[num] = resized_image

    print(f"{bone} size = ", resized_image.shape)

# bones_box = np.expand_dims(bones_box, axis=3)
# print(bones_box.shape)
plt.imshow(bones_box[0])
# Out:
# /content/bone/datasets/masks/test/153_F.png size =  (800, 800)
# /content/bone/datasets/masks/test/322_F.png size =  (800, 800)

# %%
rows = 4
cols = 4

for num, bone in enumerate(bones_box):
  # print(num)
  # print(bone[:,:,0].shape)
  num += 1
  plt.figure(figsize=(30,30))
  plt.subplot(rows, cols, num)
  plt.imshow(bone,cmap='gray')

# %%
# ground_truths = np.where(bones_box<255,'0.','255.').astype('float64')

rows = 4
cols = 4

# for num, ground_truth in enumerate(ground_truths):
for num, ground_truth in enumerate(bones_box):
  # print(num)
  num += 1
  plt.figure(figsize=(30,30))
  plt.subplot(rows, cols, num)
  image = ground_truth
  plt.imshow(image, cmap='gray')
  im = np.asarray(image)
  im = Image.fromarray(image)

  if not os.path.exists(SAVE_PATH):
    os.makedirs(SAVE_PATH)
  if not os.path.exists(Val_PATH):
    os.makedirs(Val_PATH)
  if not os.path.exists(TEST_PATH):
    os.makedirs(TEST_PATH)
  # plt.imsave(SAVE_PATH+'/'+f'{bones[num-1][:-4]}.jpeg', im)
  # np.save(os.path.join(dir_save_train, 'input_%03d.npy' % i), input_)
  num -= 1

  np.save('/content/youtube-cnn-002-pytorch-unet/datasets/test'+'/'+'label_%03d.npy' % num, im)

# %%
PATH = '/content/youtube-cnn-002-pytorch-unet/datasets/test'

bones = glob('/content/bone/datasets/imgs/test/*.png')


WIDTH = 800
HEIGHT = 800

rows = 4
cols = 4
print(bones)
bones_box = np.zeros((len(bones),WIDTH,HEIGHT))

for num, bone in enumerate(bones):
    image_pil = cv2.imread(bone,cv2.IMREAD_GRAYSCALE)
    # image_pil = Image.open(bone)
    # image = np.array(image_pil)

    grey_image = cv2.resize(image_pil,(WIDTH,HEIGHT)).astype('float64')

    # print(grey_image.shape)

    # grey_image = grey_image.reshape(WIDTH,HEIGHT)
    print(grey_image.shape)

    bones_box[num] = grey_image

    im = Image.fromarray(grey_image)

    if not os.path.exists(SAVE_PATH):
        os.makedirs(SAVE_PATH)
    np.save(PATH+'/'+'input_%03d.npy' % num, im)
# Out:
# ['/content/bone/datasets/imgs/test/153_F.png', '/content/bone/datasets/imgs/test/322_F.png']
# (800, 800)
# (800, 800)

# %%
# %cd /content/youtube-cnn-002-pytorch-unet
# Out:
# /content/youtube-cnn-002-pytorch-unet

# %%
# !python eval.py
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# TEST: BATCH 0001 / 0001 | LOSS 0.0903
# AVERAGE TEST: BATCH 0001 / 0001 | LOSS 0.0903

# %%
plt.figure(figsize=(15,15))

plt.subplot(131)
plt.imshow(np.load('/content/youtube-cnn-002-pytorch-unet/results/numpy/input_0000.npy'))

plt.subplot(132)
plt.imshow(np.load('/content/youtube-cnn-002-pytorch-unet/results/numpy/label_0000.npy'))

plt.subplot(133)
plt.imshow(np.load('/content/youtube-cnn-002-pytorch-unet/results/numpy/output_0000.npy'))

# %%
a = glob('/content/bone/datasets/masks/train/*.png')
len(a)
# Out:
# 21

# %%
shutil.copytree('/content/youtube-cnn-002-pytorch-unet','/content/drive/MyDrive/unet_practice/youtube')
# Out:
# '/content/drive/MyDrive/unet_practice/youtube'

# %%
import torch
model = torch.load('/content/drive/MyDrive/PROJECTS/unet_practice/youtube/checkpoint/model_epoch100.pth')

# %%
model('/content/drive/MyDrive/PROJECTS/2차 프로젝트 원본 데이터/데이터 원본/image/Male/001_M.jpg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-5cb674d605e6> in <module>()
# ----> 1 model('/content/drive/MyDrive/PROJECTS/2차 프로젝트 원본 데이터/데이터 원본/image/Male/001_M.jpg')
#
# TypeError: 'dict' object is not callable
