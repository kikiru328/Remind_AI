# %%
import pandas as pd

# %%
acu = pd.read_csv('전면경혈점31.csv')

# %%
acu[['중분류','중분류코드','부위','취혈']]
# Out:
#     중분류    중분류코드                                                 부위  \
# 0    영향     LI20  얼굴, 코입술고랑(nasolabial sulcus) 위, 콧방울(ala of the...
# 1    화료     LI19    얼굴, 인중 부위(philtrum)의 중점과 같은 높이, 콧구멍 가쪽모서리 아래 쪽.
# 2    관료     SI18  얼굴, 광대뼈(zygomatic bone) 아래쪽, 가쪽눈구석(outer canth...
# 3   사죽공     TE23                                 머리, 눈썹 가쪽끝의 오목한 곳.
# 4    승읍      ST1  얼굴, 동공(pupil)에서 수직으로 아래 쪽, 안구(eyeball)와 눈확아래모서...
# 5    사백      ST2                  얼굴, 눈확아래구멍(infraorbital foramen).
# 6    거료      ST3  얼굴, 동공(pupil)에서 수직으로 아래 쪽, 콧방울(ala of the nose...
# 7    지창      ST4                               얼굴, 입꼬리에서 가쪽으로 0.4寸.
# 8    두유      ST8  머리, 이마각(corner of the forehead) 前髮際(anterior h...
# 9    정명      BL1  얼굴, 안쪽눈구석(inner canthus)의 위 안쪽 부분과 눈확(orbit)의 ...
# 10   찬죽      BL2                                 머리, 눈썹 안쪽끝의 오목한 곳.
# 11   미충      BL3  머리, 이마뼈패임(frontal notch)의 위 쪽, 前髮際(anterior ha...
# 12   곡차      BL4  머리, 前髮際(anterior hairline)에서 위쪽으로 0.5寸, 앞정중선(a...
# ...
