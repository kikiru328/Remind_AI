# %%
import pandas as pd
test = pd.read_csv('cote.csv', index_col = 0)
test
# Out:
#          등록번호       도구명      평가일자  평가시간  ADL_배변  ADL_식사섭취  ADL_이동  ADL_체위변경  \
# 0     1002623  ADL_식사섭취  20180101   800       0         1       0         0
# 1     1002623    ADL_이동  20180101   800       0         0       1         0
# 2     1002623  ADL_체위변경  20180101   800       0         0       0         1
# 3     1002623   계속적인 감시  20180101   800       0         0       0         0
# 4     1002623    ADL_배변  20180101   800       1         0       0         0
# ...       ...       ...       ...   ...     ...       ...     ...       ...
# 6795  1352448  ADL_식사섭취  20180629   300       0         1       0         0
# 6796  1352448  ADL_식사섭취  20180629   300       0         1       0         0
# 6797  1352448    ADL_배변  20180629   300       1         0       0         0
# 6798  1352448    ADL_배변  20180629   300       1         0       0         0
# 6799  1352448    ADL_배변  20180629   300       1         0       0         0
#
# ...

# %%
test['발생일시'].describe
# Out:
# <bound method NDFrame.describe of 0       2018-02-06 11:00:00
# 1       2018-02-06 11:00:00
# 2       2018-02-06 11:00:00
# 3       2018-02-06 11:00:00
# 4       2018-02-06 11:00:00
#                ...
# 6795    2018-03-19 08:50:00
# 6796    2018-04-04 02:30:00
# 6797    2018-03-11 12:30:00
# 6798    2018-03-19 08:50:00
# 6799    2018-04-04 02:30:00
# Name: 발생일시, Length: 1810, dtype: object>
